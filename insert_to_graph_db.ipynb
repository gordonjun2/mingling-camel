# %%
# !pip install "camel-ai[all]==0.2.16"
# Out:
# Requirement already satisfied: camel-ai==0.2.16 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (0.2.16)
# Requirement already satisfied: colorama<1,>=0 in /usr/local/lib/python3.11/dist-packages (from camel-ai==0.2.16->camel-ai[all]==0.2.16) (0.4.6)
# Requirement already satisfied: curl_cffi==0.6.2 in /usr/local/lib/python3.11/dist-packages (from camel-ai==0.2.16->camel-ai[all]==0.2.16) (0.6.2)
# Requirement already satisfied: docstring-parser<0.16,>=0.15 in /usr/local/lib/python3.11/dist-packages (from camel-ai==0.2.16->camel-ai[all]==0.2.16) (0.15)
# Requirement already satisfied: eval-type-backport==0.2.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai==0.2.16->camel-ai[all]==0.2.16) (0.2.0)
# Requirement already satisfied: httpx<0.27.3,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai==0.2.16->camel-ai[all]==0.2.16) (0.27.2)
# Requirement already satisfied: jsonschema<5,>=4 in /usr/local/lib/python3.11/dist-packages (from camel-ai==0.2.16->camel-ai[all]==0.2.16) (4.24.0)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.11/dist-packages (from camel-ai==0.2.16->camel-ai[all]==0.2.16) (1.26.4)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in /usr/local/lib/python3.11/dist-packages (from camel-ai==0.2.16->camel-ai[all]==0.2.16) (1.91.0)
# Requirement already satisfied: pandoc in /usr/local/lib/python3.11/dist-packages (from camel-ai==0.2.16->camel-ai[all]==0.2.16) (2.4)
# Requirement already satisfied: pathlib<2.0.0,>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from camel-ai==0.2.16->camel-ai[all]==0.2.16) (1.0.1)
# Requirement already satisfied: protobuf<5,>=4 in /usr/local/lib/python3.11/dist-packages (from camel-ai==0.2.16->camel-ai[all]==0.2.16) (4.25.8)
# Requirement already satisfied: pydantic<2.10,>=1.9 in /usr/local/lib/python3.11/dist-packages (from camel-ai==0.2.16->camel-ai[all]==0.2.16) (2.9.2)
# Requirement already satisfied: tiktoken<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai==0.2.16->camel-ai[all]==0.2.16) (0.7.0)
# Requirement already satisfied: PyMuPDF<2.0.0,>=1.22.5 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (1.26.1)
# Requirement already satisfied: accelerate<1,>=0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (0.34.2)
# Requirement already satisfied: agentops<0.4.0,>=0.3.21 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (0.3.26)
# Requirement already satisfied: anthropic<0.41.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (0.40.0)
# Requirement already satisfied: apify_client<2.0.0,>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (1.12.0)
# Requirement already satisfied: arxiv<3.0.0,>=2.1.3 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (2.2.0)
# Requirement already satisfied: arxiv2text<0.2.0,>=0.1.14 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (0.1.14)
# Requirement already satisfied: asknews<0.8.0,>=0.7.54 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (0.7.58)
# Requirement already satisfied: azure-storage-blob<13.0.0,>=12.21.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (12.25.1)
# Requirement already satisfied: beautifulsoup4<5,>=4 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (4.13.4)
# Requirement already satisfied: botocore<2.0.0,>=1.35.3 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (1.39.0)
# Requirement already satisfied: cohere<6.0.0,>=5.11.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (5.15.0)
# Requirement already satisfied: dappier<0.4.0,>=0.3.3 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (0.3.6)
# Requirement already satisfied: datacommons<2.0.0,>=1.4.3 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (1.4.3)
# Requirement already satisfied: datacommons_pandas<0.0.4,>=0.0.3 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (0.0.3)
# Requirement already satisfied: datasets<4,>=3 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (3.6.0)
# Requirement already satisfied: diffusers<1,>=0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (0.34.0)
# Requirement already satisfied: discord.py<3.0.0,>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (2.5.2)
# Requirement already satisfied: docker<8.0.0,>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (7.1.0)
# Requirement already satisfied: docx2txt<0.9,>=0.8 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (0.8)
# Requirement already satisfied: duckduckgo-search<7.0.0,>=6.3.5 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (6.4.2)
# Requirement already satisfied: e2b-code-interpreter<2.0.0,>=1.0.3 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (1.2.0)
# Requirement already satisfied: ffmpeg-python<0.3.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (0.2.0)
# Requirement already satisfied: firecrawl-py<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (1.6.8)
# Requirement already satisfied: fish-audio-sdk<2025.0.0,>=2024.12.5 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (2024.12.5)
# Requirement already satisfied: google-cloud-storage<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (2.19.0)
# Requirement already satisfied: google-generativeai<0.7.0,>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (0.6.0)
# Requirement already satisfied: googlemaps<5.0.0,>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (4.10.0)
# Requirement already satisfied: imageio<3.0.0,>=2.34.2 in /usr/local/lib/python3.11/dist-packages (from imageio[pyav]<3.0.0,>=2.34.2; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (2.37.0)
# Requirement already satisfied: ipykernel<7.0.0,>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (6.17.1)
# Requirement already satisfied: jupyter_client<9.0.0,>=8.6.2 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (8.6.3)
# Requirement already satisfied: linkup-sdk<0.3.0,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (0.2.8)
# Requirement already satisfied: litellm<2.0.0,>=1.38.1 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (1.73.6)
# Requirement already satisfied: mistralai<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (1.5.2)
# Requirement already satisfied: nebula3-python==3.8.2 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (3.8.2)
# Requirement already satisfied: neo4j<6.0.0,>=5.18.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (5.28.1)
# Requirement already satisfied: newspaper3k<0.3.0,>=0.2.8 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (0.2.8)
# Requirement already satisfied: notion-client<3.0.0,>=2.2.1 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (2.4.0)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (0.7.2)
# Requirement already satisfied: openbb<5.0.0,>=4.3.5 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (4.4.4)
# Requirement already satisfied: opencv-python<5,>=4 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (4.11.0.86)
# Requirement already satisfied: outlines<0.2.0,>=0.1.7 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (0.1.14)
# Requirement already satisfied: pandas<3.0.0,>=2.2.3 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (2.3.0)
# Requirement already satisfied: pdfplumber<0.12.0,>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (0.11.7)
# Requirement already satisfied: pillow<12.0.0,>=11.0.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (11.3.0)
# Requirement already satisfied: prance<24.0.0.0,>=23.6.21.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (23.6.21.0)
# Requirement already satisfied: praw<8.0.0,>=7.7.1 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (7.8.1)
# Requirement already satisfied: pyTelegramBotAPI<5.0.0,>=4.18.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (4.27.0)
# Requirement already satisfied: pydub<0.26.0,>=0.25.1 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (0.25.1)
# Requirement already satisfied: pygithub<3.0.0,>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (2.6.1)
# Requirement already satisfied: pymilvus<3.0.0,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (2.5.11)
# Requirement already satisfied: pyowm<4.0.0,>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (3.3.0)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.2 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (6.0.2)
# Requirement already satisfied: qdrant-client<2.0.0,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (1.14.3)
# Requirement already satisfied: rank-bm25<0.3.0,>=0.2.2 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (0.2.2)
# Requirement already satisfied: redis<6.0.0,>=5.0.6 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (5.2.1)
# Requirement already satisfied: reka-api<4.0.0,>=3.0.8 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (3.2.0)
# Requirement already satisfied: requests_oauthlib<2.0.0,>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (1.3.1)
# Requirement already satisfied: rouge<2.0.0,>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (1.0.1)
# Requirement already satisfied: scholarly==1.7.11 in /usr/local/lib/python3.11/dist-packages (from scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (1.7.11)
# Requirement already satisfied: sentence-transformers<4.0.0,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (3.4.1)
# Requirement already satisfied: sentencepiece<1,>=0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (0.2.0)
# Requirement already satisfied: sglang<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (0.4.8.post1)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.20.1 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (1.23.0)
# Requirement already satisfied: slack-sdk<4.0.0,>=3.27.2 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (3.35.0)
# Requirement already satisfied: soundfile<1,>=0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (0.13.1)
# Requirement already satisfied: stripe<12.0.0,>=11.3.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (11.6.0)
# Requirement already satisfied: tavily-python<0.6.0,>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (0.5.4)
# Requirement already satisfied: textblob<0.18.0,>=0.17.1 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (0.17.1)
# Requirement already satisfied: torch<3,>=2 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (2.6.0+cu124)
# Requirement already satisfied: transformers<5,>=4 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (4.52.4)
# Requirement already satisfied: tree-sitter<0.24.0,>=0.23.2 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (0.23.2)
# Requirement already satisfied: tree-sitter-python<0.24.0,>=0.23.6 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (0.23.6)
# Requirement already satisfied: unstructured==0.16.11 in /usr/local/lib/python3.11/dist-packages (from unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (0.16.11)
# Requirement already satisfied: wikipedia<2,>=1 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (1.4.0)
# Requirement already satisfied: wolframalpha<6.0.0,>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (5.1.3)
# Requirement already satisfied: yt-dlp<2025.0.0,>=2024.11.4 in /usr/local/lib/python3.11/dist-packages (from camel-ai[all]==0.2.16) (2024.12.23)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from curl_cffi==0.6.2->camel-ai==0.2.16->camel-ai[all]==0.2.16) (1.17.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from curl_cffi==0.6.2->camel-ai==0.2.16->camel-ai[all]==0.2.16) (2025.6.15)
# Requirement already satisfied: future>=0.18.0 in /usr/local/lib/python3.11/dist-packages (from nebula3-python==3.8.2->camel-ai[all]==0.2.16) (1.0.0)
# Requirement already satisfied: httplib2>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from nebula3-python==3.8.2->camel-ai[all]==0.2.16) (0.22.0)
# Requirement already satisfied: pytz>=2021.1 in /usr/local/lib/python3.11/dist-packages (from nebula3-python==3.8.2->camel-ai[all]==0.2.16) (2025.2)
# Requirement already satisfied: six>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from nebula3-python==3.8.2->camel-ai[all]==0.2.16) (1.17.0)
# Requirement already satisfied: arrow in /usr/local/lib/python3.11/dist-packages (from scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (1.3.0)
# Requirement already satisfied: bibtexparser in /usr/local/lib/python3.11/dist-packages (from scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (1.4.3)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.11/dist-packages (from scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (1.2.18)
# Requirement already satisfied: fake-useragent in /usr/local/lib/python3.11/dist-packages (from scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (2.2.0)
# Requirement already satisfied: free-proxy in /usr/local/lib/python3.11/dist-packages (from scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (1.1.3)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (from scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (1.1.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (2.32.3)
# Requirement already satisfied: selenium in /usr/local/lib/python3.11/dist-packages (from scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (4.34.0)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.11/dist-packages (from scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (3.0.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (4.14.0)
# Requirement already satisfied: stem in /usr/local/lib/python3.11/dist-packages (from scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (1.8.2)
# Requirement already satisfied: chardet in /usr/local/lib/python3.11/dist-packages (from unstructured==0.16.11->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (5.2.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.11/dist-packages (from unstructured==0.16.11->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (1.2.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.11/dist-packages (from unstructured==0.16.11->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (0.4.27)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from unstructured==0.16.11->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (5.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from unstructured==0.16.11->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (3.9.1)
# Requirement already satisfied: emoji in /usr/local/lib/python3.11/dist-packages (from unstructured==0.16.11->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (2.14.1)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.11/dist-packages (from unstructured==0.16.11->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (0.6.7)
# Requirement already satisfied: python-iso639 in /usr/local/lib/python3.11/dist-packages (from unstructured==0.16.11->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (2025.2.18)
# Requirement already satisfied: langdetect in /usr/local/lib/python3.11/dist-packages (from unstructured==0.16.11->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (1.0.9)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.11/dist-packages (from unstructured==0.16.11->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (3.13.0)
# Requirement already satisfied: backoff in /usr/local/lib/python3.11/dist-packages (from unstructured==0.16.11->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (2.2.1)
# Requirement already satisfied: unstructured-client in /usr/local/lib/python3.11/dist-packages (from unstructured==0.16.11->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (0.28.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from unstructured==0.16.11->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (1.17.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from unstructured==0.16.11->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from unstructured==0.16.11->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (5.9.8)
# Requirement already satisfied: python-oxmsg in /usr/local/lib/python3.11/dist-packages (from unstructured==0.16.11->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (0.0.2)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.11/dist-packages (from unstructured==0.16.11->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (1.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (3.5)
# Requirement already satisfied: unstructured-inference==0.8.1 in /usr/local/lib/python3.11/dist-packages (from unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (0.8.1)
# Requirement already satisfied: google-cloud-vision in /usr/local/lib/python3.11/dist-packages (from unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (3.10.2)
# Requirement already satisfied: pi-heif in /usr/local/lib/python3.11/dist-packages (from unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (1.0.0)
# Requirement already satisfied: python-pptx>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (1.0.2)
# Requirement already satisfied: pikepdf in /usr/local/lib/python3.11/dist-packages (from unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (9.9.0)
# Requirement already satisfied: markdown in /usr/local/lib/python3.11/dist-packages (from unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (3.8.2)
# Requirement already satisfied: pypdf in /usr/local/lib/python3.11/dist-packages (from unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (5.7.0)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (from unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (3.1.5)
# Requirement already satisfied: pdfminer.six in /usr/local/lib/python3.11/dist-packages (from unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (20250506)
# Requirement already satisfied: pdf2image in /usr/local/lib/python3.11/dist-packages (from unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (1.17.0)
# Requirement already satisfied: effdet in /usr/local/lib/python3.11/dist-packages (from unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (0.4.1)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.11/dist-packages (from unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (2.0.2)
# Requirement already satisfied: onnx in /usr/local/lib/python3.11/dist-packages (from unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (1.18.0)
# Requirement already satisfied: pypandoc in /usr/local/lib/python3.11/dist-packages (from unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (1.15)
# Requirement already satisfied: python-docx>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (1.2.0)
# Requirement already satisfied: unstructured.pytesseract>=0.3.12 in /usr/local/lib/python3.11/dist-packages (from unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (0.3.15)
# Requirement already satisfied: layoutparser in /usr/local/lib/python3.11/dist-packages (from unstructured-inference==0.8.1->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (0.3.4)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.11/dist-packages (from unstructured-inference==0.8.1->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (0.0.20)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.11/dist-packages (from unstructured-inference==0.8.1->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (0.33.0)
# Requirement already satisfied: onnxruntime>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from unstructured-inference==0.8.1->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (1.22.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from unstructured-inference==0.8.1->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (3.10.0)
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (from unstructured-inference==0.8.1->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (1.0.15)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate<1,>=0->camel-ai[all]==0.2.16) (24.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate<1,>=0->camel-ai[all]==0.2.16) (0.5.3)
# Requirement already satisfied: opentelemetry-api>=1.27.0 in /usr/local/lib/python3.11/dist-packages (from agentops<0.4.0,>=0.3.21->camel-ai[all]==0.2.16) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.27.0 in /usr/local/lib/python3.11/dist-packages (from agentops<0.4.0,>=0.3.21->camel-ai[all]==0.2.16) (1.27.0)
# Requirement already satisfied: opentelemetry-sdk>=1.27.0 in /usr/local/lib/python3.11/dist-packages (from agentops<0.4.0,>=0.3.21->camel-ai[all]==0.2.16) (1.27.0)
# Requirement already satisfied: termcolor<2.5.0,>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from agentops<0.4.0,>=0.3.21->camel-ai[all]==0.2.16) (2.4.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from anthropic<0.41.0,>=0.40.0->camel-ai[all]==0.2.16) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from anthropic<0.41.0,>=0.40.0->camel-ai[all]==0.2.16) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from anthropic<0.41.0,>=0.40.0->camel-ai[all]==0.2.16) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from anthropic<0.41.0,>=0.40.0->camel-ai[all]==0.2.16) (1.3.1)
# Requirement already satisfied: apify-shared>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from apify_client<2.0.0,>=1.8.1->camel-ai[all]==0.2.16) (1.4.1)
# Requirement already satisfied: more-itertools>=10.0.0 in /usr/local/lib/python3.11/dist-packages (from apify_client<2.0.0,>=1.8.1->camel-ai[all]==0.2.16) (10.7.0)
# Requirement already satisfied: feedparser~=6.0.10 in /usr/local/lib/python3.11/dist-packages (from arxiv<3.0.0,>=2.1.3->camel-ai[all]==0.2.16) (6.0.11)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from arxiv2text<0.2.0,>=0.1.14->camel-ai[all]==0.2.16) (1.6.1)
# Requirement already satisfied: PyPDF2 in /usr/local/lib/python3.11/dist-packages (from arxiv2text<0.2.0,>=0.1.14->camel-ai[all]==0.2.16) (3.0.1)
# Requirement already satisfied: asgiref<4.0.0,>=3.7.2 in /usr/local/lib/python3.11/dist-packages (from asknews<0.8.0,>=0.7.54->camel-ai[all]==0.2.16) (3.8.1)
# Requirement already satisfied: cryptography<42.0.7,>=40.0.0 in /usr/local/lib/python3.11/dist-packages (from asknews<0.8.0,>=0.7.54->camel-ai[all]==0.2.16) (42.0.6)
# Requirement already satisfied: orjson<4.0.0,>=3.9.10 in /usr/local/lib/python3.11/dist-packages (from asknews<0.8.0,>=0.7.54->camel-ai[all]==0.2.16) (3.10.18)
# Requirement already satisfied: azure-core>=1.30.0 in /usr/local/lib/python3.11/dist-packages (from azure-storage-blob<13.0.0,>=12.21.0->camel-ai[all]==0.2.16) (1.34.0)
# Requirement already satisfied: isodate>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from azure-storage-blob<13.0.0,>=12.21.0->camel-ai[all]==0.2.16) (0.7.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4<5,>=4->camel-ai[all]==0.2.16) (2.7)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from botocore<2.0.0,>=1.35.3->camel-ai[all]==0.2.16) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<2.0.0,>=1.35.3->camel-ai[all]==0.2.16) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<2.0.0,>=1.35.3->camel-ai[all]==0.2.16) (2.4.0)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /usr/local/lib/python3.11/dist-packages (from cohere<6.0.0,>=5.11.0->camel-ai[all]==0.2.16) (1.11.1)
# Requirement already satisfied: httpx-sse==0.4.0 in /usr/local/lib/python3.11/dist-packages (from cohere<6.0.0,>=5.11.0->camel-ai[all]==0.2.16) (0.4.0)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in /usr/local/lib/python3.11/dist-packages (from cohere<6.0.0,>=5.11.0->camel-ai[all]==0.2.16) (2.23.4)
# Requirement already satisfied: tokenizers<1,>=0.15 in /usr/local/lib/python3.11/dist-packages (from cohere<6.0.0,>=5.11.0->camel-ai[all]==0.2.16) (0.21.2)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from cohere<6.0.0,>=5.11.0->camel-ai[all]==0.2.16) (2.32.4.20250611)
# Requirement already satisfied: asyncio<4.0.0,>=3.4.3 in /usr/local/lib/python3.11/dist-packages (from dappier<0.4.0,>=0.3.3->camel-ai[all]==0.2.16) (3.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets<4,>=3->camel-ai[all]==0.2.16) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets<4,>=3->camel-ai[all]==0.2.16) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets<4,>=3->camel-ai[all]==0.2.16) (0.3.7)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets<4,>=3->camel-ai[all]==0.2.16) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets<4,>=3->camel-ai[all]==0.2.16) (0.70.15)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4,>=3->camel-ai[all]==0.2.16) (2025.3.0)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.11/dist-packages (from diffusers<1,>=0->camel-ai[all]==0.2.16) (8.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from diffusers<1,>=0->camel-ai[all]==0.2.16) (2024.11.6)
# Requirement already satisfied: aiohttp<4,>=3.7.4 in /usr/local/lib/python3.11/dist-packages (from discord.py<3.0.0,>=2.3.2->camel-ai[all]==0.2.16) (3.11.15)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.11/dist-packages (from duckduckgo-search<7.0.0,>=6.3.5->camel-ai[all]==0.2.16) (8.2.1)
# Requirement already satisfied: primp>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from duckduckgo-search<7.0.0,>=6.3.5->camel-ai[all]==0.2.16) (0.15.0)
# Requirement already satisfied: attrs>=21.3.0 in /usr/local/lib/python3.11/dist-packages (from e2b-code-interpreter<2.0.0,>=1.0.3->camel-ai[all]==0.2.16) (25.3.0)
# Requirement already satisfied: e2b<2.0.0,>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from e2b-code-interpreter<2.0.0,>=1.0.3->camel-ai[all]==0.2.16) (1.3.3)
# Requirement already satisfied: websockets in /usr/local/lib/python3.11/dist-packages (from firecrawl-py<2.0.0,>=1.0.0->camel-ai[all]==0.2.16) (15.0.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from firecrawl-py<2.0.0,>=1.0.0->camel-ai[all]==0.2.16) (1.6.0)
# Requirement already satisfied: ormsgpack>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from fish-audio-sdk<2025.0.0,>=2024.12.5->camel-ai[all]==0.2.16) (1.10.0)
# Requirement already satisfied: httpx-ws>=0.6.2 in /usr/local/lib/python3.11/dist-packages (from fish-audio-sdk<2025.0.0,>=2024.12.5->camel-ai[all]==0.2.16) (0.7.2)
# Requirement already satisfied: google-auth<3.0dev,>=2.26.1 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage<3.0.0,>=2.18.0->camel-ai[all]==0.2.16) (2.38.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage<3.0.0,>=2.18.0->camel-ai[all]==0.2.16) (2.25.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage<3.0.0,>=2.18.0->camel-ai[all]==0.2.16) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage<3.0.0,>=2.18.0->camel-ai[all]==0.2.16) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage<3.0.0,>=2.18.0->camel-ai[all]==0.2.16) (1.7.1)
# Requirement already satisfied: google-ai-generativelanguage==0.6.4 in /usr/local/lib/python3.11/dist-packages (from google-generativeai<0.7.0,>=0.6.0->camel-ai[all]==0.2.16) (0.6.4)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (from google-generativeai<0.7.0,>=0.6.0->camel-ai[all]==0.2.16) (2.173.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage==0.6.4->google-generativeai<0.7.0,>=0.6.0->camel-ai[all]==0.2.16) (1.26.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<0.27.3,>=0.23.0->camel-ai==0.2.16->camel-ai[all]==0.2.16) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx<0.27.3,>=0.23.0->camel-ai==0.2.16->camel-ai[all]==0.2.16) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<0.27.3,>=0.23.0->camel-ai==0.2.16->camel-ai[all]==0.2.16) (0.16.0)
# Requirement already satisfied: av in /usr/local/lib/python3.11/dist-packages (from imageio[pyav]<3.0.0,>=2.34.2; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (14.4.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel<7.0.0,>=6.0.0->camel-ai[all]==0.2.16) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel<7.0.0,>=6.0.0->camel-ai[all]==0.2.16) (7.34.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel<7.0.0,>=6.0.0->camel-ai[all]==0.2.16) (0.1.7)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel<7.0.0,>=6.0.0->camel-ai[all]==0.2.16) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel<7.0.0,>=6.0.0->camel-ai[all]==0.2.16) (6.4.2)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel<7.0.0,>=6.0.0->camel-ai[all]==0.2.16) (5.7.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5,>=4->camel-ai==0.2.16->camel-ai[all]==0.2.16) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5,>=4->camel-ai==0.2.16->camel-ai[all]==0.2.16) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5,>=4->camel-ai==0.2.16->camel-ai[all]==0.2.16) (0.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.11/dist-packages (from jupyter_client<9.0.0,>=8.6.2->camel-ai[all]==0.2.16) (5.8.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from litellm<2.0.0,>=1.38.1->camel-ai[all]==0.2.16) (3.1.6)
# Requirement already satisfied: jsonpath-python>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from mistralai<2.0.0,>=1.1.0->camel-ai[all]==0.2.16) (1.0.6)
# Requirement already satisfied: typing-inspect>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from mistralai<2.0.0,>=1.1.0->camel-ai[all]==0.2.16) (0.9.0)
# Requirement already satisfied: cssselect>=0.9.2 in /usr/local/lib/python3.11/dist-packages (from newspaper3k<0.3.0,>=0.2.8->camel-ai[all]==0.2.16) (1.3.0)
# Requirement already satisfied: tldextract>=2.0.1 in /usr/local/lib/python3.11/dist-packages (from newspaper3k<0.3.0,>=0.2.8->camel-ai[all]==0.2.16) (5.3.0)
# Requirement already satisfied: feedfinder2>=0.0.4 in /usr/local/lib/python3.11/dist-packages (from newspaper3k<0.3.0,>=0.2.8->camel-ai[all]==0.2.16) (0.0.4)
# Requirement already satisfied: jieba3k>=0.35.1 in /usr/local/lib/python3.11/dist-packages (from newspaper3k<0.3.0,>=0.2.8->camel-ai[all]==0.2.16) (0.35.1)
# Requirement already satisfied: tinysegmenter==0.3 in /usr/local/lib/python3.11/dist-packages (from newspaper3k<0.3.0,>=0.2.8->camel-ai[all]==0.2.16) (0.3)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from openapi-spec-validator<0.8.0,>=0.7.1->camel-ai[all]==0.2.16) (0.3.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in /usr/local/lib/python3.11/dist-packages (from openapi-spec-validator<0.8.0,>=0.7.1->camel-ai[all]==0.2.16) (1.11.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from openapi-spec-validator<0.8.0,>=0.7.1->camel-ai[all]==0.2.16) (0.6.3)
# Requirement already satisfied: openbb-benzinga<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.4.1)
# Requirement already satisfied: openbb-bls<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.1.2)
# Requirement already satisfied: openbb-cftc<2.0.0,>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.1.1)
# Requirement already satisfied: openbb-commodity<2.0.0,>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.3.1)
# Requirement already satisfied: openbb-core<2.0.0,>=1.4.6 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.4.7)
# Requirement already satisfied: openbb-crypto<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.4.1)
# Requirement already satisfied: openbb-currency<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.4.1)
# Requirement already satisfied: openbb-derivatives<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.4.1)
# Requirement already satisfied: openbb-econdb<2.0.0,>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.3.1)
# Requirement already satisfied: openbb-economy<2.0.0,>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.4.2)
# Requirement already satisfied: openbb-equity<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.4.1)
# Requirement already satisfied: openbb-etf<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.4.1)
# Requirement already satisfied: openbb-federal-reserve<2.0.0,>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.4.3)
# Requirement already satisfied: openbb-fixedincome<2.0.0,>=1.4.3 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.4.3)
# Requirement already satisfied: openbb-fmp<2.0.0,>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.4.2)
# Requirement already satisfied: openbb-fred<2.0.0,>=1.4.4 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.4.4)
# Requirement already satisfied: openbb-imf<2.0.0,>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.1.1)
# Requirement already satisfied: openbb-index<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.4.1)
# Requirement already satisfied: openbb-intrinio<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.4.1)
# Requirement already satisfied: openbb-news<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.4.1)
# Requirement already satisfied: openbb-oecd<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.4.1)
# Requirement already satisfied: openbb-platform-api<2.0.0,>=1.1.6 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.1.10)
# Requirement already satisfied: openbb-polygon<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.4.1)
# Requirement already satisfied: openbb-regulators<2.0.0,>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.4.2)
# Requirement already satisfied: openbb-sec<2.0.0,>=1.4.3 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.4.3)
# Requirement already satisfied: openbb-tiingo<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.4.1)
# Requirement already satisfied: openbb-tradingeconomics<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.4.1)
# Requirement already satisfied: openbb-us-eia<2.0.0,>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.1.1)
# Requirement already satisfied: openbb-yfinance<2.0.0,>=1.4.3 in /usr/local/lib/python3.11/dist-packages (from openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.4.3)
# Requirement already satisfied: interegular in /usr/local/lib/python3.11/dist-packages (from outlines<0.2.0,>=0.1.7->camel-ai[all]==0.2.16) (0.3.3)
# Requirement already satisfied: lark in /usr/local/lib/python3.11/dist-packages (from outlines<0.2.0,>=0.1.7->camel-ai[all]==0.2.16) (1.2.2)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from outlines<0.2.0,>=0.1.7->camel-ai[all]==0.2.16) (3.1.1)
# Requirement already satisfied: diskcache in /usr/local/lib/python3.11/dist-packages (from outlines<0.2.0,>=0.1.7->camel-ai[all]==0.2.16) (5.6.3)
# Requirement already satisfied: pycountry in /usr/local/lib/python3.11/dist-packages (from outlines<0.2.0,>=0.1.7->camel-ai[all]==0.2.16) (24.6.1)
# Requirement already satisfied: airportsdata in /usr/local/lib/python3.11/dist-packages (from outlines<0.2.0,>=0.1.7->camel-ai[all]==0.2.16) (20250622)
# Requirement already satisfied: outlines_core==0.1.26 in /usr/local/lib/python3.11/dist-packages (from outlines<0.2.0,>=0.1.7->camel-ai[all]==0.2.16) (0.1.26)
# Requirement already satisfied: genson in /usr/local/lib/python3.11/dist-packages (from outlines<0.2.0,>=0.1.7->camel-ai[all]==0.2.16) (1.3.0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=2.2.3->camel-ai[all]==0.2.16) (2025.2)
# Requirement already satisfied: pypdfium2>=4.18.0 in /usr/local/lib/python3.11/dist-packages (from pdfplumber<0.12.0,>=0.11.0->camel-ai[all]==0.2.16) (4.30.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (3.4.2)
# Requirement already satisfied: ruamel.yaml>=0.17.10 in /usr/local/lib/python3.11/dist-packages (from prance<24.0.0.0,>=23.6.21.0->camel-ai[all]==0.2.16) (0.18.14)
# Requirement already satisfied: prawcore<3,>=2.4 in /usr/local/lib/python3.11/dist-packages (from praw<8.0.0,>=7.7.1->camel-ai[all]==0.2.16) (2.4.0)
# Requirement already satisfied: update_checker>=0.18 in /usr/local/lib/python3.11/dist-packages (from praw<8.0.0,>=7.7.1->camel-ai[all]==0.2.16) (0.18.0)
# Requirement already satisfied: websocket-client>=0.54.0 in /usr/local/lib/python3.11/dist-packages (from praw<8.0.0,>=7.7.1->camel-ai[all]==0.2.16) (1.8.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.10,>=1.9->camel-ai==0.2.16->camel-ai[all]==0.2.16) (0.7.0)
# Requirement already satisfied: pynacl>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from pygithub<3.0.0,>=2.3.0->camel-ai[all]==0.2.16) (1.5.0)
# Requirement already satisfied: pyjwt>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.4.0->pygithub<3.0.0,>=2.3.0->camel-ai[all]==0.2.16) (2.10.1)
# Requirement already satisfied: setuptools>69 in /usr/local/lib/python3.11/dist-packages (from pymilvus<3.0.0,>=2.4.0->camel-ai[all]==0.2.16) (75.2.0)
# Requirement already satisfied: grpcio<=1.67.1,>=1.49.1 in /usr/local/lib/python3.11/dist-packages (from pymilvus<3.0.0,>=2.4.0->camel-ai[all]==0.2.16) (1.67.1)
# Requirement already satisfied: ujson>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pymilvus<3.0.0,>=2.4.0->camel-ai[all]==0.2.16) (5.10.0)
# Requirement already satisfied: milvus-lite>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from pymilvus<3.0.0,>=2.4.0->camel-ai[all]==0.2.16) (2.5.1)
# Requirement already satisfied: geojson<3,>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from pyowm<4.0.0,>=3.3.0->camel-ai[all]==0.2.16) (2.5.0)
# Requirement already satisfied: PySocks<2,>=1.7.1 in /usr/local/lib/python3.11/dist-packages (from pyowm<4.0.0,>=3.3.0->camel-ai[all]==0.2.16) (1.7.1)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in /usr/local/lib/python3.11/dist-packages (from qdrant-client<2.0.0,>=1.9.0->camel-ai[all]==0.2.16) (2.10.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests_oauthlib<2.0.0,>=1.3.1->camel-ai[all]==0.2.16) (3.3.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers<4.0.0,>=3.0.1->camel-ai[all]==0.2.16) (1.15.3)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from sglang<0.5.0,>=0.4.0->camel-ai[all]==0.2.16) (1.3.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->camel-ai[all]==0.2.16) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->camel-ai[all]==0.2.16) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->camel-ai[all]==0.2.16) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->camel-ai[all]==0.2.16) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->camel-ai[all]==0.2.16) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->camel-ai[all]==0.2.16) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2->camel-ai[all]==0.2.16) (10.3.5.147)
# ...
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (2.0.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.27.0->agentops<0.4.0,>=0.3.21->camel-ai[all]==0.2.16) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.27.0->agentops<0.4.0,>=0.3.21->camel-ai[all]==0.2.16) (1.27.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-sdk>=1.27.0->agentops<0.4.0,>=0.3.21->camel-ai[all]==0.2.16) (0.48b0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from python-pptx>=1.0.1->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (3.2.5)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.11/dist-packages (from ruamel.yaml>=0.17.10->prance<24.0.0.0,>=23.6.21.0->camel-ai[all]==0.2.16) (0.2.12)
# Requirement already satisfied: requests-file>=1.4 in /usr/local/lib/python3.11/dist-packages (from tldextract>=2.0.1->newspaper3k<0.3.0,>=0.2.8->camel-ai[all]==0.2.16) (2.1.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect>=0.9.0->mistralai<2.0.0,>=1.1.0->camel-ai[all]==0.2.16) (1.1.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /usr/local/lib/python3.11/dist-packages (from arrow->scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (2.9.0.20250516)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json->unstructured==0.16.11->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (3.26.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from effdet->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (0.21.0+cu124)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from effdet->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (2.0.10)
# Requirement already satisfied: omegaconf>=2.0 in /usr/local/lib/python3.11/dist-packages (from effdet->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (2.3.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai<0.7.0,>=0.6.0->camel-ai[all]==0.2.16) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai<0.7.0,>=0.6.0->camel-ai[all]==0.2.16) (4.2.0)
# Requirement already satisfied: backports.tarfile in /usr/local/lib/python3.11/dist-packages (from jaraco.context->wolframalpha<6.0.0,>=5.0.0->camel-ai[all]==0.2.16) (1.2.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.11/dist-packages (from python-oxmsg->unstructured==0.16.11->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (0.47)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->arxiv2text<0.2.0,>=0.1.14->camel-ai[all]==0.2.16) (3.6.0)
# Requirement already satisfied: trio~=0.30.0 in /usr/local/lib/python3.11/dist-packages (from selenium->scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.12.2 in /usr/local/lib/python3.11/dist-packages (from selenium->scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (0.12.2)
# Requirement already satisfied: sphinx<9,>=6 in /usr/local/lib/python3.11/dist-packages (from sphinx-rtd-theme->scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (8.2.3)
# Requirement already satisfied: docutils<0.22,>0.18 in /usr/local/lib/python3.11/dist-packages (from sphinx-rtd-theme->scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (0.21.2)
# Requirement already satisfied: sphinxcontrib-jquery<5,>=4 in /usr/local/lib/python3.11/dist-packages (from sphinx-rtd-theme->scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (4.1)
# Requirement already satisfied: aiofiles>=24.1.0 in /usr/local/lib/python3.11/dist-packages (from unstructured-client->unstructured==0.16.11->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (24.1.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from unstructured-client->unstructured==0.16.11->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (1.0.0)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp-client-cache<0.12.0,>=0.11.0->openbb-econdb<2.0.0,>=1.3.1->openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (2.2.0)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in /usr/local/lib/python3.11/dist-packages (from aiohttp-client-cache<0.12.0,>=0.11.0->openbb-econdb<2.0.0,>=1.3.1->openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.4.3)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi<0.116,>=0.115->openbb-core<2.0.0,>=1.4.6->openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (0.46.2)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.4->google-generativeai<0.7.0,>=0.6.0->camel-ai[all]==0.2.16) (1.62.3)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.11/dist-packages (from h2<5,>=3->httpx[http2]>=0.22.0->nebula3-python==3.8.2->camel-ai[all]==0.2.16) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.11/dist-packages (from h2<5,>=3->httpx[http2]>=0.22.0->nebula3-python==3.8.2->camel-ai[all]==0.2.16) (4.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel<7.0.0,>=6.0.0->camel-ai[all]==0.2.16) (0.8.4)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from omegaconf>=2.0->effdet->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (4.9.3)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.17.0->unstructured-inference==0.8.1->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.17.0->unstructured-inference==0.8.1->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (25.2.10)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel<7.0.0,>=6.0.0->camel-ai[all]==0.2.16) (0.7.0)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.11/dist-packages (from posthog<4.0.0,>=3.3.1->openbb-core<2.0.0,>=1.4.6->openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.6)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel<7.0.0,>=6.0.0->camel-ai[all]==0.2.16) (0.2.13)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0.0,>=2.18.0->camel-ai[all]==0.2.16) (0.6.1)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.11/dist-packages (from requests-cache<2.0.0,>=1.1.0->openbb-intrinio<2.0.0,>=1.4.1->openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (25.1.1)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=6->sphinx-rtd-theme->scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=6->sphinx-rtd-theme->scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=6->sphinx-rtd-theme->scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=6->sphinx-rtd-theme->scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=6->sphinx-rtd-theme->scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=6->sphinx-rtd-theme->scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (2.0.0)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=6->sphinx-rtd-theme->scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=6->sphinx-rtd-theme->scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=6->sphinx-rtd-theme->scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=6->sphinx-rtd-theme->scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (1.4.1)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=6->sphinx-rtd-theme->scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (3.1.0)
# Requirement already satisfied: courlan>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.3->openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.3.2)
# Requirement already satisfied: htmldate>=1.9.2 in /usr/local/lib/python3.11/dist-packages (from trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.3->openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.9.3)
# Requirement already satisfied: justext>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.3->openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (3.0.2)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium->scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (2.4.0)
# Requirement already satisfied: outcome in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium->scholarly==1.7.11->scholarly[tor]==1.7.11; extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (1.3.0.post0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance<0.3.0,>=0.2.56->openbb-yfinance<2.0.0,>=1.4.3->openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (0.0.11)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/dist-packages (from yfinance<0.3.0,>=0.2.56->openbb-yfinance<2.0.0,>=1.4.3->openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/dist-packages (from yfinance<0.3.0,>=0.2.56->openbb-yfinance<2.0.0,>=1.4.3->openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (3.18.1)
# Requirement already satisfied: orderly-set<6,>=5.4.1 in /usr/local/lib/python3.11/dist-packages (from deepdiff->openbb-platform-api<2.0.0,>=1.1.6->openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (5.4.1)
# Requirement already satisfied: iopath in /usr/local/lib/python3.11/dist-packages (from layoutparser->unstructured-inference==0.8.1->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (0.1.10)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->unstructured-inference==0.8.1->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->unstructured-inference==0.8.1->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->unstructured-inference==0.8.1->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->unstructured-inference==0.8.1->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (1.4.8)
# Requirement already satisfied: tld>=0.13 in /usr/local/lib/python3.11/dist-packages (from courlan>=1.3.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.3->openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (0.13.1)
# Requirement already satisfied: dateparser>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from htmldate>=1.9.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.3->openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (1.2.2)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.11/dist-packages (from coloredlogs->onnxruntime>=1.17.0->unstructured-inference==0.8.1->unstructured[all-docs]==0.16.11; extra == "rag" or extra == "tools" or extra == "all"->camel-ai[all]==0.2.16) (10.0)
# Requirement already satisfied: tzlocal>=0.2 in /usr/local/lib/python3.11/dist-packages (from dateparser>=1.1.2->htmldate>=1.9.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.3->openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (5.3.1)
# Requirement already satisfied: lxml_html_clean in /usr/local/lib/python3.11/dist-packages (from lxml[html_clean]>=4.4.2->justext>=3.0.1->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.3->openbb<5.0.0,>=4.3.5->camel-ai[all]==0.2.16) (0.4.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)

# %%
from camel.models import ModelFactory
from camel.types import ModelPlatformType, ModelType
from camel.configs import MistralConfig, OllamaConfig
from camel.loaders import UnstructuredIO
from camel.storages import Neo4jGraph
from camel.retrievers import AutoRetriever
from camel.embeddings import MistralEmbedding
from camel.types import StorageType
from camel.agents import ChatAgent, KnowledgeGraphAgent
from camel.messages import BaseMessage
from langchain_openai import ChatOpenAI
from camel.configs import ChatGPTConfig
import pandas as pd
import pickle
import os
import numpy as np
from google.colab import userdata
import sys

sys.modules['numpy._core.numeric'] = np.core.numeric

# %%
def load_pickle_to_dataframe(file_path):
    """
    Load a pickle file and convert it to a pandas DataFrame

    Args:
        file_path (str): Path to the pickle file

    Returns:
        pd.DataFrame: The loaded DataFrame
    """
    try:
        # Check if file exists
        if not os.path.exists(file_path):
            raise FileNotFoundError(f"The file {file_path} does not exist")

        # Load the pickle file
        with open(file_path, 'rb') as f:
            data = pickle.load(f)

        # Convert to DataFrame if it's not already one
        if not isinstance(data, pd.DataFrame):
            data = pd.DataFrame(data)

        return data

    except Exception as e:
        print(f"Error loading the pickle file: {str(e)}")
        return None

# %%
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
NEO4J_URI = userdata.get('NEO4J_URI')
NEO4J_USERNAME = userdata.get('NEO4J_USERNAME')
NEO4J_PASSWORD = userdata.get('NEO4J_PASSWORD')

# %%
# Specify the path to your .pkl file
pkl_path = './summarised_data/summarised_family_pig.pkl'

# Initialise LLM and RAG agent
llm = ModelFactory.create(
    model_platform=ModelPlatformType.OPENAI,
    model_type=ModelType.GPT_4O_MINI,
    model_config_dict=ChatGPTConfig(temperature=0.7).as_dict(),
    api_key=OPENAI_API_KEY,
)
uio = UnstructuredIO()
kg_agent = KnowledgeGraphAgent(model=llm)

# Set Neo4j instance
try:
    n4j = Neo4jGraph(
        url=NEO4J_URI,
        username=NEO4J_USERNAME,
        password=NEO4J_PASSWORD,
    )
    print("CAMEL Neo4jGraph initialized successfully")
except Exception as e:
    print("CAMEL Neo4jGraph error:", str(e))
# Out:
# CAMEL Neo4jGraph initialized successfully

# %%
# Load the data
print("Loading data from pickle file...")
df = load_pickle_to_dataframe(pkl_path)
print(f"Loaded {len(df)} rows of data")

# Generate the graph
for i, row in enumerate(df.itertuples(index=True)):
    print(f"\nProcessing row {i+1}/{len(df)}")

    text = f"{row.summarisedComment} This message was posted on the date {row.date}."
    element = uio.create_element_from_text(text=text,
                                            element_id=str(row.Index))
    graph_elements = kg_agent.run(element, parse_graph_elements=True)
    n4j.add_graph_elements(graph_elements=[graph_elements])
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Processing row 2351/4850
#
# Processing row 2352/4850
#
# Processing row 2353/4850
#
# Processing row 2354/4850
#
# Processing row 2355/4850
#
# Processing row 2356/4850
#
# Processing row 2357/4850
#
# Processing row 2358/4850
#
# Processing row 2359/4850
#
# Processing row 2360/4850
#
# Processing row 2361/4850
#
# Processing row 2362/4850
#
# Processing row 2363/4850
#
# Processing row 2364/4850
#
# Processing row 2365/4850
#
# Processing row 2366/4850
#
# Processing row 2367/4850
#
# Processing row 2368/4850
#
# Processing row 2369/4850
#
# Processing row 2370/4850
#
# Processing row 2371/4850
#
# Processing row 2372/4850
#
# Processing row 2373/4850
#
# Processing row 2374/4850
#
# Processing row 2375/4850
#
# Processing row 2376/4850
#
# Processing row 2377/4850
#
# Processing row 2378/4850
#
# Processing row 2379/4850
#
# Processing row 2380/4850
#
# Processing row 2381/4850
#
# Processing row 2382/4850
#
# Processing row 2383/4850
#
# Processing row 2384/4850
#
# Processing row 2385/4850
#
# Processing row 2386/4850
#
# Processing row 2387/4850
#
# Processing row 2388/4850
#
# Processing row 2389/4850
#
# Processing row 2390/4850
#
# Processing row 2391/4850
#
# Processing row 2392/4850
#
# Processing row 2393/4850
#
# Processing row 2394/4850
#
# Processing row 2395/4850
#
# Processing row 2396/4850
#
# Processing row 2397/4850
#
# Processing row 2398/4850
#
# Processing row 2399/4850
#
# Processing row 2400/4850
#
# Processing row 2401/4850
#
# Processing row 2402/4850
#
# Processing row 2403/4850
#
# Processing row 2404/4850
#
# Processing row 2405/4850
#
# Processing row 2406/4850
#
# Processing row 2407/4850
#
# Processing row 2408/4850
#
# Processing row 2409/4850
#
# Processing row 2410/4850
#
# Processing row 2411/4850
#
# Processing row 2412/4850
#
# Processing row 2413/4850
#
# Processing row 2414/4850
#
# Processing row 2415/4850
#
# Processing row 2416/4850
#
# Processing row 2417/4850
#
# Processing row 2418/4850
#
# Processing row 2419/4850
#
# Processing row 2420/4850
#
# Processing row 2421/4850
#
# Processing row 2422/4850
#
# Processing row 2423/4850
#
# Processing row 2424/4850
#
# Processing row 2425/4850
#
# Processing row 2426/4850
#
# Processing row 2427/4850
#
# Processing row 2428/4850
#
# Processing row 2429/4850
#
# Processing row 2430/4850
#
# Processing row 2431/4850
#
# Processing row 2432/4850
#
# Processing row 2433/4850
#
# Processing row 2434/4850
#
# Processing row 2435/4850
#
# Processing row 2436/4850
#
# Processing row 2437/4850
#
# Processing row 2438/4850
#
# Processing row 2439/4850
#
# Processing row 2440/4850
#
# Processing row 2441/4850
#
# Processing row 2442/4850
#
# Processing row 2443/4850
#
# Processing row 2444/4850
#
# Processing row 2445/4850
#
# Processing row 2446/4850
#
# Processing row 2447/4850
#
# Processing row 2448/4850
#
# Processing row 2449/4850
#
# Processing row 2450/4850
#
# Processing row 2451/4850
#
# Processing row 2452/4850
#
# Processing row 2453/4850
#
# Processing row 2454/4850
#
# Processing row 2455/4850
#
# Processing row 2456/4850
#
# Processing row 2457/4850
#
# Processing row 2458/4850
#
# Processing row 2459/4850
#
# Processing row 2460/4850
#
# Processing row 2461/4850
#
# Processing row 2462/4850
#
# Processing row 2463/4850
#
# Processing row 2464/4850
#
# Processing row 2465/4850
#
# Processing row 2466/4850
#
# Processing row 2467/4850
#
# Processing row 2468/4850
#
# Processing row 2469/4850
#
# Processing row 2470/4850
#
# Processing row 2471/4850
#
# Processing row 2472/4850
#
# Processing row 2473/4850
#
# Processing row 2474/4850
#
# Processing row 2475/4850
#
# Processing row 2476/4850
#
# Processing row 2477/4850
#
# Processing row 2478/4850
#
# Processing row 2479/4850
#
# Processing row 2480/4850
#
# Processing row 2481/4850
#
# Processing row 2482/4850
#
# Processing row 2483/4850
#
# Processing row 2484/4850
#
# Processing row 2485/4850
#
# Processing row 2486/4850
#
# Processing row 2487/4850
#
# Processing row 2488/4850
#
# Processing row 2489/4850
#
# Processing row 2490/4850
#
# Processing row 2491/4850
#
# Processing row 2492/4850
#
# Processing row 2493/4850
#
# Processing row 2494/4850
#
# Processing row 2495/4850
#
# Processing row 2496/4850
#
# Processing row 2497/4850
#
# Processing row 2498/4850
#
# Processing row 2499/4850
#
# Processing row 2500/4850
#
# Processing row 2501/4850
#
# Processing row 2502/4850
#
# Processing row 2503/4850
#
# Processing row 2504/4850
#
# Processing row 2505/4850
#
# Processing row 2506/4850
#
# Processing row 2507/4850
#
# Processing row 2508/4850
#
# Processing row 2509/4850
#
# Processing row 2510/4850
#
# Processing row 2511/4850
#
# Processing row 2512/4850
#
# Processing row 2513/4850
#
# Processing row 2514/4850
#
# Processing row 2515/4850
#
# Processing row 2516/4850
#
# Processing row 2517/4850
#
# Processing row 2518/4850
#
# Processing row 2519/4850
#
# Processing row 2520/4850
#
# Processing row 2521/4850
#
# Processing row 2522/4850
#
# Processing row 2523/4850
#
# Processing row 2524/4850
#
# Processing row 2525/4850
#
# Processing row 2526/4850
#
# Processing row 2527/4850
#
# Processing row 2528/4850
#
# Processing row 2529/4850
#
# Processing row 2530/4850
#
# Processing row 2531/4850
#
# Processing row 2532/4850
#
# Processing row 2533/4850
#
# Processing row 2534/4850
#
# Processing row 2535/4850
#
# Processing row 2536/4850
#
# Processing row 2537/4850
#
# Processing row 2538/4850
#
# Processing row 2539/4850
#
# Processing row 2540/4850
#
# Processing row 2541/4850
#
# Processing row 2542/4850
#
# Processing row 2543/4850
#
# Processing row 2544/4850
#
# Processing row 2545/4850
#
# Processing row 2546/4850
#
# Processing row 2547/4850
#
# Processing row 2548/4850
#
# Processing row 2549/4850
#
# Processing row 2550/4850
#
# Processing row 2551/4850
#
# Processing row 2552/4850
#
# Processing row 2553/4850
#
# Processing row 2554/4850
#
# Processing row 2555/4850
#
# Processing row 2556/4850
#
# Processing row 2557/4850
#
# Processing row 2558/4850
#
# Processing row 2559/4850
#
# Processing row 2560/4850
#
# Processing row 2561/4850
#
# Processing row 2562/4850
#
# Processing row 2563/4850
#
# Processing row 2564/4850
#
# Processing row 2565/4850
#
# Processing row 2566/4850
#
# Processing row 2567/4850
#
# Processing row 2568/4850
#
# Processing row 2569/4850
#
# Processing row 2570/4850
#
# Processing row 2571/4850
#
# Processing row 2572/4850
#
# Processing row 2573/4850
#
# Processing row 2574/4850
#
# Processing row 2575/4850
#
# Processing row 2576/4850
#
# Processing row 2577/4850
#
# Processing row 2578/4850
#
# Processing row 2579/4850
#
# Processing row 2580/4850
#
# Processing row 2581/4850
#
# Processing row 2582/4850
#
# Processing row 2583/4850
#
# Processing row 2584/4850
#
# Processing row 2585/4850
#
# Processing row 2586/4850
#
# Processing row 2587/4850
#
# Processing row 2588/4850
#
# Processing row 2589/4850
#
# Processing row 2590/4850
#
# Processing row 2591/4850
#
# Processing row 2592/4850
#
# Processing row 2593/4850
#
# Processing row 2594/4850
#
# Processing row 2595/4850
#
# Processing row 2596/4850
#
# Processing row 2597/4850
#
# Processing row 2598/4850
#
# Processing row 2599/4850
#
# Processing row 2600/4850
#
# Processing row 2601/4850
#
# Processing row 2602/4850
#
# Processing row 2603/4850
#
# Processing row 2604/4850
#
# Processing row 2605/4850
#
# Processing row 2606/4850
#
# Processing row 2607/4850
#
# Processing row 2608/4850
#
# Processing row 2609/4850
#
# Processing row 2610/4850
#
# Processing row 2611/4850
#
# Processing row 2612/4850
#
# Processing row 2613/4850
#
# Processing row 2614/4850
#
# Processing row 2615/4850
#
# Processing row 2616/4850
#
# Processing row 2617/4850
#
# Processing row 2618/4850
#
# Processing row 2619/4850
#
# Processing row 2620/4850
#
# Processing row 2621/4850
#
# Processing row 2622/4850
#
# Processing row 2623/4850
#
# Processing row 2624/4850
#
# Processing row 2625/4850
#
# Processing row 2626/4850
#
# Processing row 2627/4850
#
# Processing row 2628/4850
#
# Processing row 2629/4850
#
# Processing row 2630/4850
#
# Processing row 2631/4850
#
# Processing row 2632/4850
#
# Processing row 2633/4850
#
# Processing row 2634/4850
#
# Processing row 2635/4850
#
# Processing row 2636/4850
#
# Processing row 2637/4850
#
# Processing row 2638/4850
#
# Processing row 2639/4850
#
# Processing row 2640/4850
#
# Processing row 2641/4850
#
# Processing row 2642/4850
#
# Processing row 2643/4850
#
# Processing row 2644/4850
#
# Processing row 2645/4850
#
# Processing row 2646/4850
#
# Processing row 2647/4850
#
# Processing row 2648/4850
#
# Processing row 2649/4850
#
# Processing row 2650/4850
#
# Processing row 2651/4850
#
# Processing row 2652/4850
#
# Processing row 2653/4850
#
# Processing row 2654/4850
#
# Processing row 2655/4850
#
# Processing row 2656/4850
#
# Processing row 2657/4850
#
# Processing row 2658/4850
#
# Processing row 2659/4850
#
# Processing row 2660/4850
#
# Processing row 2661/4850
#
# Processing row 2662/4850
#
# Processing row 2663/4850
#
# Processing row 2664/4850
#
# Processing row 2665/4850
#
# Processing row 2666/4850
#
# Processing row 2667/4850
#
# Processing row 2668/4850
#
# Processing row 2669/4850
#
# Processing row 2670/4850
#
# Processing row 2671/4850
#
# Processing row 2672/4850
#
# Processing row 2673/4850
#
# Processing row 2674/4850
#
# Processing row 2675/4850
#
# Processing row 2676/4850
#
# Processing row 2677/4850
#
# Processing row 2678/4850
#
# Processing row 2679/4850
#
# Processing row 2680/4850
#
# Processing row 2681/4850
#
# Processing row 2682/4850
#
# Processing row 2683/4850
#
# Processing row 2684/4850
#
# Processing row 2685/4850
#
# Processing row 2686/4850
#
# Processing row 2687/4850
#
# Processing row 2688/4850
#
# Processing row 2689/4850
#
# Processing row 2690/4850
#
# Processing row 2691/4850
#
# Processing row 2692/4850
#
# Processing row 2693/4850
#
# Processing row 2694/4850
#
# Processing row 2695/4850
#
# Processing row 2696/4850
#
# Processing row 2697/4850
#
# Processing row 2698/4850
#
# Processing row 2699/4850
#
# Processing row 2700/4850
#
# Processing row 2701/4850
#
# Processing row 2702/4850
#
# Processing row 2703/4850
#
# Processing row 2704/4850
#
# Processing row 2705/4850
#
# Processing row 2706/4850
#
# Processing row 2707/4850
#
# Processing row 2708/4850
#
# Processing row 2709/4850
#
# Processing row 2710/4850
#
# Processing row 2711/4850
#
# Processing row 2712/4850
#
# Processing row 2713/4850
#
# Processing row 2714/4850
#
# Processing row 2715/4850
#
# Processing row 2716/4850
#
# Processing row 2717/4850
#
# Processing row 2718/4850
#
# Processing row 2719/4850
#
# Processing row 2720/4850
#
# Processing row 2721/4850
#
# Processing row 2722/4850
#
# Processing row 2723/4850
#
# Processing row 2724/4850
#
# Processing row 2725/4850
#
# Processing row 2726/4850
#
# Processing row 2727/4850
#
# Processing row 2728/4850
#
# Processing row 2729/4850
#
# Processing row 2730/4850
#
# Processing row 2731/4850
#
# Processing row 2732/4850
#
# Processing row 2733/4850
#
# Processing row 2734/4850
#
# Processing row 2735/4850
#
# Processing row 2736/4850
#
# Processing row 2737/4850
#
# Processing row 2738/4850
#
# Processing row 2739/4850
#
# Processing row 2740/4850
#
# Processing row 2741/4850
#
# Processing row 2742/4850
#
# Processing row 2743/4850
#
# Processing row 2744/4850
#
# Processing row 2745/4850
#
# Processing row 2746/4850
#
# Processing row 2747/4850
#
# Processing row 2748/4850
#
# Processing row 2749/4850
#
# Processing row 2750/4850
#
# Processing row 2751/4850
#
# Processing row 2752/4850
#
# Processing row 2753/4850
#
# Processing row 2754/4850
#
# Processing row 2755/4850
#
# Processing row 2756/4850
#
# Processing row 2757/4850
#
# Processing row 2758/4850
#
# Processing row 2759/4850
#
# Processing row 2760/4850
#
# Processing row 2761/4850
#
# Processing row 2762/4850
#
# Processing row 2763/4850
#
# Processing row 2764/4850
#
# Processing row 2765/4850
#
# Processing row 2766/4850
#
# Processing row 2767/4850
#
# Processing row 2768/4850
#
# Processing row 2769/4850
#
# Processing row 2770/4850
#
# Processing row 2771/4850
#
# Processing row 2772/4850
#
# Processing row 2773/4850
#
# Processing row 2774/4850
#
# Processing row 2775/4850
#
# Processing row 2776/4850
#
# Processing row 2777/4850
#
# Processing row 2778/4850
#
# Processing row 2779/4850
#
# Processing row 2780/4850
#
# Processing row 2781/4850
#
# Processing row 2782/4850
#
# Processing row 2783/4850
#
# Processing row 2784/4850
#
# Processing row 2785/4850
#
# Processing row 2786/4850
#
# Processing row 2787/4850
#
# Processing row 2788/4850
#
# Processing row 2789/4850
#
# Processing row 2790/4850
#
# Processing row 2791/4850
#
# Processing row 2792/4850
#
# Processing row 2793/4850
#
# Processing row 2794/4850
#
# Processing row 2795/4850
#
# Processing row 2796/4850
#
# Processing row 2797/4850
#
# Processing row 2798/4850
#
# Processing row 2799/4850
#
# Processing row 2800/4850
#
# Processing row 2801/4850
#
# Processing row 2802/4850
#
# Processing row 2803/4850
#
# Processing row 2804/4850
#
# Processing row 2805/4850
#
# Processing row 2806/4850
#
# Processing row 2807/4850
#
# Processing row 2808/4850
#
# Processing row 2809/4850
#
# Processing row 2810/4850
#
# Processing row 2811/4850
#
# Processing row 2812/4850
#
# Processing row 2813/4850
#
# Processing row 2814/4850
#
# Processing row 2815/4850
#
# Processing row 2816/4850
#
# Processing row 2817/4850
#
# Processing row 2818/4850
#
# Processing row 2819/4850
#
# Processing row 2820/4850
#
# Processing row 2821/4850
#
# Processing row 2822/4850
#
# Processing row 2823/4850
#
# Processing row 2824/4850
#
# Processing row 2825/4850
#
# Processing row 2826/4850
#
# Processing row 2827/4850
#
# Processing row 2828/4850
#
# Processing row 2829/4850
#
# Processing row 2830/4850
#
# Processing row 2831/4850
#
# Processing row 2832/4850
#
# Processing row 2833/4850
#
# Processing row 2834/4850
#
# Processing row 2835/4850
#
# Processing row 2836/4850
#
# Processing row 2837/4850
#
# Processing row 2838/4850
#
# Processing row 2839/4850
#
# Processing row 2840/4850
#
# Processing row 2841/4850
#
# Processing row 2842/4850
#
# Processing row 2843/4850
#
# Processing row 2844/4850
#
# Processing row 2845/4850
#
# Processing row 2846/4850
#
# Processing row 2847/4850
#
# Processing row 2848/4850
#
# Processing row 2849/4850
#
# Processing row 2850/4850
#
# Processing row 2851/4850
#
# Processing row 2852/4850
#
# Processing row 2853/4850
#
# Processing row 2854/4850
#
# Processing row 2855/4850
#
# Processing row 2856/4850
#
# Processing row 2857/4850
#
# Processing row 2858/4850
#
# Processing row 2859/4850
#
# Processing row 2860/4850
#
# Processing row 2861/4850
#
# Processing row 2862/4850
#
# Processing row 2863/4850
#
# Processing row 2864/4850
#
# Processing row 2865/4850
#
# Processing row 2866/4850
#
# Processing row 2867/4850
#
# Processing row 2868/4850
#
# Processing row 2869/4850
#
# Processing row 2870/4850
#
# Processing row 2871/4850
#
# Processing row 2872/4850
#
# Processing row 2873/4850
#
# Processing row 2874/4850
#
# Processing row 2875/4850
#
# Processing row 2876/4850
#
# Processing row 2877/4850
#
# Processing row 2878/4850
#
# Processing row 2879/4850
#
# Processing row 2880/4850
#
# Processing row 2881/4850
#
# Processing row 2882/4850
#
# Processing row 2883/4850
#
# Processing row 2884/4850
#
# Processing row 2885/4850
#
# Processing row 2886/4850
#
# Processing row 2887/4850
#
# Processing row 2888/4850
#
# Processing row 2889/4850
#
# Processing row 2890/4850
#
# Processing row 2891/4850
#
# Processing row 2892/4850
#
# Processing row 2893/4850
#
# Processing row 2894/4850
#
# Processing row 2895/4850
#
# Processing row 2896/4850
#
# Processing row 2897/4850
#
# Processing row 2898/4850
#
# Processing row 2899/4850
#
# Processing row 2900/4850
#
# Processing row 2901/4850
#
# Processing row 2902/4850
#
# Processing row 2903/4850
#
# Processing row 2904/4850
#
# Processing row 2905/4850
#
# Processing row 2906/4850
#
# Processing row 2907/4850
#
# Processing row 2908/4850
#
# Processing row 2909/4850
#
# Processing row 2910/4850
#
# Processing row 2911/4850
#
# Processing row 2912/4850
#
# Processing row 2913/4850
#
# Processing row 2914/4850
#
# Processing row 2915/4850
#
# Processing row 2916/4850
#
# Processing row 2917/4850
#
# Processing row 2918/4850
#
# Processing row 2919/4850
#
# Processing row 2920/4850
#
# Processing row 2921/4850
#
# Processing row 2922/4850
#
# Processing row 2923/4850
#
# Processing row 2924/4850
#
# Processing row 2925/4850
#
# Processing row 2926/4850
#
# Processing row 2927/4850
#
# Processing row 2928/4850
#
# Processing row 2929/4850
#
# Processing row 2930/4850
#
# Processing row 2931/4850
#
# Processing row 2932/4850
#
# Processing row 2933/4850
#
# Processing row 2934/4850
#
# Processing row 2935/4850
#
# Processing row 2936/4850
#
# Processing row 2937/4850
#
# Processing row 2938/4850
#
# Processing row 2939/4850
#
# Processing row 2940/4850
#
# Processing row 2941/4850
#
# Processing row 2942/4850
#
# Processing row 2943/4850
#
# Processing row 2944/4850
#
# Processing row 2945/4850
#
# Processing row 2946/4850
#
# Processing row 2947/4850
#
# Processing row 2948/4850
#
# Processing row 2949/4850
#
# Processing row 2950/4850
#
# Processing row 2951/4850
#
# Processing row 2952/4850
#
# Processing row 2953/4850
#
# Processing row 2954/4850
#
# Processing row 2955/4850
#
# Processing row 2956/4850
#
# Processing row 2957/4850
#
# Processing row 2958/4850
#
# Processing row 2959/4850
#
# Processing row 2960/4850
#
# Processing row 2961/4850
#
# Processing row 2962/4850
#
# Processing row 2963/4850
#
# Processing row 2964/4850
#
# Processing row 2965/4850
#
# Processing row 2966/4850
#
# Processing row 2967/4850
#
# Processing row 2968/4850
#
# Processing row 2969/4850
#
# Processing row 2970/4850
#
# Processing row 2971/4850
#
# Processing row 2972/4850
#
# Processing row 2973/4850
#
# Processing row 2974/4850
#
# Processing row 2975/4850
#
# Processing row 2976/4850
#
# Processing row 2977/4850
#
# Processing row 2978/4850
#
# Processing row 2979/4850
#
# Processing row 2980/4850
#
# Processing row 2981/4850
#
# Processing row 2982/4850
#
# Processing row 2983/4850
#
# Processing row 2984/4850
#
# Processing row 2985/4850
#
# Processing row 2986/4850
#
# Processing row 2987/4850
#
# Processing row 2988/4850
#
# Processing row 2989/4850
#
# Processing row 2990/4850
#
# Processing row 2991/4850
#
# Processing row 2992/4850
#
# Processing row 2993/4850
#
# Processing row 2994/4850
#
# Processing row 2995/4850
#
# Processing row 2996/4850
#
# Processing row 2997/4850
#
# Processing row 2998/4850
#
# Processing row 2999/4850
#
# Processing row 3000/4850
#
# Processing row 3001/4850
#
# Processing row 3002/4850
#
# Processing row 3003/4850
#
# Processing row 3004/4850
#
# Processing row 3005/4850
#
# Processing row 3006/4850
#
# Processing row 3007/4850
#
# Processing row 3008/4850
#
# Processing row 3009/4850
#
# Processing row 3010/4850
#
# Processing row 3011/4850
#
# Processing row 3012/4850
#
# Processing row 3013/4850
#
# Processing row 3014/4850
#
# Processing row 3015/4850
#
# Processing row 3016/4850
#
# Processing row 3017/4850
#
# Processing row 3018/4850
#
# Processing row 3019/4850
#
# Processing row 3020/4850
#
# Processing row 3021/4850
#
# Processing row 3022/4850
#
# Processing row 3023/4850
#
# Processing row 3024/4850
#
# Processing row 3025/4850
#
# Processing row 3026/4850
#
# Processing row 3027/4850
#
# Processing row 3028/4850
#
# Processing row 3029/4850
#
# Processing row 3030/4850
#
# Processing row 3031/4850
#
# Processing row 3032/4850
#
# Processing row 3033/4850
#
# Processing row 3034/4850
#
# Processing row 3035/4850
#
# Processing row 3036/4850
#
# Processing row 3037/4850
#
# Processing row 3038/4850
#
# Processing row 3039/4850
#
# Processing row 3040/4850
#
# Processing row 3041/4850
#
# Processing row 3042/4850
#
# Processing row 3043/4850
#
# Processing row 3044/4850
#
# Processing row 3045/4850
#
# Processing row 3046/4850
#
# Processing row 3047/4850
#
# Processing row 3048/4850
#
# Processing row 3049/4850
#
# Processing row 3050/4850
#
# Processing row 3051/4850
#
# Processing row 3052/4850
#
# Processing row 3053/4850
#
# Processing row 3054/4850
#
# Processing row 3055/4850
#
# Processing row 3056/4850
#
# Processing row 3057/4850
#
# Processing row 3058/4850
#
# Processing row 3059/4850
#
# Processing row 3060/4850
#
# Processing row 3061/4850
#
# Processing row 3062/4850
#
# Processing row 3063/4850
#
# Processing row 3064/4850
#
# Processing row 3065/4850
#
# Processing row 3066/4850
#
# Processing row 3067/4850
#
# Processing row 3068/4850
#
# Processing row 3069/4850
#
# Processing row 3070/4850
#
# Processing row 3071/4850
#
# Processing row 3072/4850
#
# Processing row 3073/4850
#
# Processing row 3074/4850
#
# Processing row 3075/4850
#
# Processing row 3076/4850
#
# Processing row 3077/4850
#
# Processing row 3078/4850
#
# Processing row 3079/4850
#
# Processing row 3080/4850
#
# Processing row 3081/4850
#
# Processing row 3082/4850
#
# Processing row 3083/4850
#
# Processing row 3084/4850
#
# Processing row 3085/4850
#
# Processing row 3086/4850
#
# Processing row 3087/4850
#
# Processing row 3088/4850
#
# Processing row 3089/4850
#
# Processing row 3090/4850
#
# Processing row 3091/4850
#
# Processing row 3092/4850
#
# Processing row 3093/4850
#
# Processing row 3094/4850
#
# Processing row 3095/4850
#
# Processing row 3096/4850
#
# Processing row 3097/4850
#
# Processing row 3098/4850
#
# Processing row 3099/4850
#
# Processing row 3100/4850
#
# Processing row 3101/4850
#
# Processing row 3102/4850
#
# Processing row 3103/4850
#
# Processing row 3104/4850
#
# Processing row 3105/4850
#
# Processing row 3106/4850
#
# Processing row 3107/4850
#
# Processing row 3108/4850
#
# Processing row 3109/4850
#
# Processing row 3110/4850
#
# Processing row 3111/4850
#
# Processing row 3112/4850
#
# Processing row 3113/4850
#
# Processing row 3114/4850
#
# Processing row 3115/4850
#
# Processing row 3116/4850
#
# Processing row 3117/4850
#
# Processing row 3118/4850
#
# Processing row 3119/4850
#
# Processing row 3120/4850
#
# Processing row 3121/4850
#
# Processing row 3122/4850
#
# Processing row 3123/4850
#
# Processing row 3124/4850
#
# Processing row 3125/4850
#
# Processing row 3126/4850
#
# Processing row 3127/4850
#
# Processing row 3128/4850
#
# Processing row 3129/4850
#
# Processing row 3130/4850
#
# Processing row 3131/4850
#
# Processing row 3132/4850
#
# Processing row 3133/4850
#
# Processing row 3134/4850
#
# Processing row 3135/4850
#
# Processing row 3136/4850
#
# Processing row 3137/4850
#
# Processing row 3138/4850
#
# Processing row 3139/4850
#
# Processing row 3140/4850
#
# Processing row 3141/4850
#
# Processing row 3142/4850
#
# Processing row 3143/4850
#
# Processing row 3144/4850
#
# Processing row 3145/4850
#
# Processing row 3146/4850
#
# Processing row 3147/4850
#
# Processing row 3148/4850
#
# Processing row 3149/4850
#
# Processing row 3150/4850
#
# Processing row 3151/4850
#
# Processing row 3152/4850
#
# Processing row 3153/4850
#
# Processing row 3154/4850
#
# Processing row 3155/4850
#
# Processing row 3156/4850
#
# Processing row 3157/4850
#
# Processing row 3158/4850
#
# Processing row 3159/4850
#
# Processing row 3160/4850
#
# Processing row 3161/4850
#
# Processing row 3162/4850
#
# Processing row 3163/4850
#
# Processing row 3164/4850
#
# Processing row 3165/4850
#
# Processing row 3166/4850
#
# Processing row 3167/4850
#
# Processing row 3168/4850
#
# Processing row 3169/4850
#
# Processing row 3170/4850
#
# Processing row 3171/4850
#
# Processing row 3172/4850
#
# Processing row 3173/4850
#
# Processing row 3174/4850
#
# Processing row 3175/4850
#
# Processing row 3176/4850
#
# Processing row 3177/4850
#
# Processing row 3178/4850
#
# Processing row 3179/4850
#
# Processing row 3180/4850
#
# Processing row 3181/4850
#
# Processing row 3182/4850
#
# Processing row 3183/4850
#
# Processing row 3184/4850
#
# Processing row 3185/4850
#
# Processing row 3186/4850
#
# Processing row 3187/4850
#
# Processing row 3188/4850
#
# Processing row 3189/4850
#
# Processing row 3190/4850
#
# Processing row 3191/4850
#
# Processing row 3192/4850
#
# Processing row 3193/4850
#
# Processing row 3194/4850
#
# Processing row 3195/4850
#
# Processing row 3196/4850
#
# Processing row 3197/4850
#
# Processing row 3198/4850
#
# Processing row 3199/4850
#
# Processing row 3200/4850
#
# Processing row 3201/4850
#
# Processing row 3202/4850
#
# Processing row 3203/4850
#
# Processing row 3204/4850
#
# Processing row 3205/4850
#
# Processing row 3206/4850
#
# Processing row 3207/4850
#
# Processing row 3208/4850
#
# Processing row 3209/4850
#
# Processing row 3210/4850
#
# Processing row 3211/4850
#
# Processing row 3212/4850
#
# Processing row 3213/4850
#
# Processing row 3214/4850
#
# Processing row 3215/4850
#
# Processing row 3216/4850
#
# Processing row 3217/4850
#
# Processing row 3218/4850
#
# Processing row 3219/4850
#
# Processing row 3220/4850
#
# Processing row 3221/4850
#
# Processing row 3222/4850
#
# Processing row 3223/4850
#
# Processing row 3224/4850
#
# Processing row 3225/4850
#
# Processing row 3226/4850
#
# Processing row 3227/4850
#
# Processing row 3228/4850
#
# Processing row 3229/4850
#
# Processing row 3230/4850
#
# Processing row 3231/4850
#
# Processing row 3232/4850
#
# Processing row 3233/4850
#
# Processing row 3234/4850
#
# Processing row 3235/4850
#
# Processing row 3236/4850
#
# Processing row 3237/4850
#
# Processing row 3238/4850
#
# Processing row 3239/4850
#
# Processing row 3240/4850
#
# Processing row 3241/4850
#
# Processing row 3242/4850
#
# Processing row 3243/4850
#
# Processing row 3244/4850
#
# Processing row 3245/4850
#
# Processing row 3246/4850
#
# Processing row 3247/4850
#
# Processing row 3248/4850
#
# Processing row 3249/4850
#
# Processing row 3250/4850
#
# Processing row 3251/4850
#
# Processing row 3252/4850
#
# Processing row 3253/4850
#
# Processing row 3254/4850
#
# Processing row 3255/4850
#
# Processing row 3256/4850
#
# Processing row 3257/4850
#
# Processing row 3258/4850
#
# Processing row 3259/4850
#
# Processing row 3260/4850
#
# Processing row 3261/4850
#
# Processing row 3262/4850
#
# Processing row 3263/4850
#
# Processing row 3264/4850
#
# Processing row 3265/4850
#
# Processing row 3266/4850
#
# Processing row 3267/4850
#
# Processing row 3268/4850
#
# Processing row 3269/4850
#
# Processing row 3270/4850
#
# Processing row 3271/4850
#
# Processing row 3272/4850
#
# Processing row 3273/4850
#
# Processing row 3274/4850
#
# Processing row 3275/4850
#
# Processing row 3276/4850
#
# Processing row 3277/4850
#
# Processing row 3278/4850
#
# Processing row 3279/4850
#
# Processing row 3280/4850
#
# Processing row 3281/4850
#
# Processing row 3282/4850
#
# Processing row 3283/4850
#
# Processing row 3284/4850
#
# Processing row 3285/4850
#
# Processing row 3286/4850
#
# Processing row 3287/4850
#
# Processing row 3288/4850
#
# Processing row 3289/4850
#
# Processing row 3290/4850
#
# Processing row 3291/4850
#
# Processing row 3292/4850
#
# Processing row 3293/4850
#
# Processing row 3294/4850
#
# Processing row 3295/4850
#
# Processing row 3296/4850
#
# Processing row 3297/4850
#
# Processing row 3298/4850
#
# Processing row 3299/4850
#
# Processing row 3300/4850
#
# Processing row 3301/4850
#
# Processing row 3302/4850
#
# Processing row 3303/4850
#
# Processing row 3304/4850
#
# Processing row 3305/4850
#
# Processing row 3306/4850
#
# Processing row 3307/4850
#
# Processing row 3308/4850
#
# Processing row 3309/4850
#
# Processing row 3310/4850
#
# Processing row 3311/4850
#
# Processing row 3312/4850
#
# Processing row 3313/4850
#
# Processing row 3314/4850
#
# Processing row 3315/4850
#
# Processing row 3316/4850
#
# Processing row 3317/4850
#
# Processing row 3318/4850
#
# Processing row 3319/4850
#
# Processing row 3320/4850
#
# Processing row 3321/4850
#
# Processing row 3322/4850
#
# Processing row 3323/4850
#
# Processing row 3324/4850
#
# Processing row 3325/4850
#
# Processing row 3326/4850
#
# Processing row 3327/4850
#
# Processing row 3328/4850
#
# Processing row 3329/4850
#
# Processing row 3330/4850
#
# Processing row 3331/4850
#
# Processing row 3332/4850
#
# Processing row 3333/4850
#
# Processing row 3334/4850
#
# Processing row 3335/4850
#
# Processing row 3336/4850
#
# Processing row 3337/4850
#
# Processing row 3338/4850
#
# Processing row 3339/4850
#
# Processing row 3340/4850
#
# Processing row 3341/4850
#
# Processing row 3342/4850
#
# Processing row 3343/4850
#
# Processing row 3344/4850
#
# Processing row 3345/4850
#
# Processing row 3346/4850
#
# Processing row 3347/4850
#
# Processing row 3348/4850
#
# Processing row 3349/4850
#
# Processing row 3350/4850
#
# Processing row 3351/4850
#
# Processing row 3352/4850
#
# Processing row 3353/4850
#
# Processing row 3354/4850
#
# Processing row 3355/4850
#
# Processing row 3356/4850
#
# Processing row 3357/4850
#
# Processing row 3358/4850
#
# Processing row 3359/4850
#
# Processing row 3360/4850
#
# Processing row 3361/4850
#
# Processing row 3362/4850
#
# Processing row 3363/4850
#
# Processing row 3364/4850
#
# Processing row 3365/4850
#
# Processing row 3366/4850
#
# Processing row 3367/4850
#
# Processing row 3368/4850
#
# Processing row 3369/4850
#
# Processing row 3370/4850
#
# Processing row 3371/4850
#
# Processing row 3372/4850
#
# Processing row 3373/4850
#
# Processing row 3374/4850
#
# Processing row 3375/4850
#
# Processing row 3376/4850
#
# Processing row 3377/4850
#
# Processing row 3378/4850
#
# Processing row 3379/4850
#
# Processing row 3380/4850
#
# Processing row 3381/4850
#
# Processing row 3382/4850
#
# Processing row 3383/4850
#
# Processing row 3384/4850
#
# Processing row 3385/4850
#
# Processing row 3386/4850
#
# Processing row 3387/4850
#
# Processing row 3388/4850
#
# Processing row 3389/4850
#
# Processing row 3390/4850
#
# Processing row 3391/4850
#
# Processing row 3392/4850
#
# Processing row 3393/4850
#
# Processing row 3394/4850
#
# Processing row 3395/4850
#
# Processing row 3396/4850
#
# Processing row 3397/4850
#
# Processing row 3398/4850
#
# Processing row 3399/4850
#
# Processing row 3400/4850
#
# Processing row 3401/4850
#
# Processing row 3402/4850
#
# Processing row 3403/4850
#
# Processing row 3404/4850
#
# Processing row 3405/4850
#
# Processing row 3406/4850
#
# Processing row 3407/4850
#
# Processing row 3408/4850
#
# Processing row 3409/4850
#
# Processing row 3410/4850
#
# Processing row 3411/4850
#
# Processing row 3412/4850
#
# Processing row 3413/4850
#
# Processing row 3414/4850
#
# Processing row 3415/4850
#
# Processing row 3416/4850
#
# Processing row 3417/4850
#
# Processing row 3418/4850
#
# Processing row 3419/4850
#
# Processing row 3420/4850
#
# Processing row 3421/4850
#
# Processing row 3422/4850
#
# Processing row 3423/4850
#
# Processing row 3424/4850
#
# Processing row 3425/4850
#
# Processing row 3426/4850
#
# Processing row 3427/4850
#
# Processing row 3428/4850
#
# Processing row 3429/4850
#
# Processing row 3430/4850
#
# Processing row 3431/4850
#
# Processing row 3432/4850
#
# Processing row 3433/4850
#
# Processing row 3434/4850
#
# Processing row 3435/4850
#
# Processing row 3436/4850
#
# Processing row 3437/4850
#
# Processing row 3438/4850
#
# Processing row 3439/4850
#
# Processing row 3440/4850
#
# Processing row 3441/4850
#
# Processing row 3442/4850
#
# Processing row 3443/4850
#
# Processing row 3444/4850
#
# Processing row 3445/4850
#
# Processing row 3446/4850
#
# Processing row 3447/4850
#
# Processing row 3448/4850
#
# Processing row 3449/4850
#
# Processing row 3450/4850
#
# Processing row 3451/4850
#
# Processing row 3452/4850
#
# Processing row 3453/4850
#
# Processing row 3454/4850
#
# Processing row 3455/4850
#
# Processing row 3456/4850
#
# Processing row 3457/4850
#
# Processing row 3458/4850
#
# Processing row 3459/4850
#
# Processing row 3460/4850
#
# Processing row 3461/4850
#
# Processing row 3462/4850
#
# Processing row 3463/4850
#
# Processing row 3464/4850
#
# Processing row 3465/4850
#
# Processing row 3466/4850
#
# Processing row 3467/4850
#
# Processing row 3468/4850
#
# Processing row 3469/4850
#
# Processing row 3470/4850
#
# Processing row 3471/4850
#
# Processing row 3472/4850
#
# Processing row 3473/4850
#
# Processing row 3474/4850
#
# Processing row 3475/4850
#
# Processing row 3476/4850
#
# Processing row 3477/4850
#
# Processing row 3478/4850
#
# Processing row 3479/4850
#
# Processing row 3480/4850
#
# Processing row 3481/4850
#
# Processing row 3482/4850
#
# Processing row 3483/4850
#
# Processing row 3484/4850
#
# Processing row 3485/4850
#
# Processing row 3486/4850
#
# Processing row 3487/4850
#
# Processing row 3488/4850
#
# Processing row 3489/4850
#
# Processing row 3490/4850
#
# Processing row 3491/4850
#
# Processing row 3492/4850
#
# Processing row 3493/4850
#
# Processing row 3494/4850
#
# Processing row 3495/4850
#
# Processing row 3496/4850
#
# Processing row 3497/4850
#
# Processing row 3498/4850
#
# Processing row 3499/4850
#
# Processing row 3500/4850
#
# Processing row 3501/4850
#
# Processing row 3502/4850
#
# Processing row 3503/4850
#
# Processing row 3504/4850
#
# Processing row 3505/4850
#
# Processing row 3506/4850
#
# Processing row 3507/4850
#
# Processing row 3508/4850
#
# Processing row 3509/4850
#
# Processing row 3510/4850
#
# Processing row 3511/4850
#
# Processing row 3512/4850
#
# Processing row 3513/4850
#
# Processing row 3514/4850
#
# Processing row 3515/4850
#
# Processing row 3516/4850
#
# Processing row 3517/4850
#
# Processing row 3518/4850
#
# Processing row 3519/4850
#
# Processing row 3520/4850
#
# Processing row 3521/4850
#
# Processing row 3522/4850
#
# Processing row 3523/4850
#
# Processing row 3524/4850
#
# Processing row 3525/4850
#
# Processing row 3526/4850
#
# Processing row 3527/4850
#
# Processing row 3528/4850
#
# Processing row 3529/4850
#
# Processing row 3530/4850
#
# Processing row 3531/4850
#
# Processing row 3532/4850
#
# Processing row 3533/4850
#
# Processing row 3534/4850
#
# Processing row 3535/4850
#
# Processing row 3536/4850
#
# Processing row 3537/4850
#
# Processing row 3538/4850
#
# Processing row 3539/4850
#
# Processing row 3540/4850
#
# Processing row 3541/4850
#
# Processing row 3542/4850
#
# Processing row 3543/4850
#
# Processing row 3544/4850
#
# Processing row 3545/4850
#
# Processing row 3546/4850
#
# Processing row 3547/4850
#
# Processing row 3548/4850
#
# Processing row 3549/4850
#
# Processing row 3550/4850
#
# Processing row 3551/4850
#
# Processing row 3552/4850
#
# Processing row 3553/4850
#
# Processing row 3554/4850
#
# Processing row 3555/4850
#
# Processing row 3556/4850
#
# Processing row 3557/4850
#
# Processing row 3558/4850
#
# Processing row 3559/4850
#
# Processing row 3560/4850
#
# Processing row 3561/4850
#
# Processing row 3562/4850
#
# Processing row 3563/4850
#
# Processing row 3564/4850
#
# Processing row 3565/4850
#
# Processing row 3566/4850
#
# Processing row 3567/4850
#
# Processing row 3568/4850
#
# Processing row 3569/4850
#
# Processing row 3570/4850
#
# Processing row 3571/4850
#
# Processing row 3572/4850
#
# Processing row 3573/4850
#
# Processing row 3574/4850
#
# Processing row 3575/4850
#
# Processing row 3576/4850
#
# Processing row 3577/4850
#
# Processing row 3578/4850
#
# Processing row 3579/4850
#
# Processing row 3580/4850
#
# Processing row 3581/4850
#
# Processing row 3582/4850
#
# Processing row 3583/4850
#
# Processing row 3584/4850
#
# Processing row 3585/4850
#
# Processing row 3586/4850
#
# Processing row 3587/4850
#
# Processing row 3588/4850
#
# Processing row 3589/4850
#
# Processing row 3590/4850
#
# Processing row 3591/4850
#
# Processing row 3592/4850
#
# Processing row 3593/4850
#
# Processing row 3594/4850
#
# Processing row 3595/4850
#
# Processing row 3596/4850
#
# Processing row 3597/4850
#
# Processing row 3598/4850
#
# Processing row 3599/4850
#
# Processing row 3600/4850
#
# Processing row 3601/4850
#
# Processing row 3602/4850
#
# Processing row 3603/4850
#
# Processing row 3604/4850
#
# Processing row 3605/4850
#
# Processing row 3606/4850
#
# Processing row 3607/4850
#
# Processing row 3608/4850
#
# Processing row 3609/4850
#
# Processing row 3610/4850
#
# Processing row 3611/4850
#
# Processing row 3612/4850
#
# Processing row 3613/4850
#
# Processing row 3614/4850
#
# Processing row 3615/4850
#
# Processing row 3616/4850
#
# Processing row 3617/4850
#
# Processing row 3618/4850
#
# Processing row 3619/4850
#
# Processing row 3620/4850
#
# Processing row 3621/4850
#
# Processing row 3622/4850
#
# Processing row 3623/4850
#
# Processing row 3624/4850
#
# Processing row 3625/4850
#
# Processing row 3626/4850
#
# Processing row 3627/4850
#
# Processing row 3628/4850
#
# Processing row 3629/4850
#
# Processing row 3630/4850
#
# Processing row 3631/4850
#
# Processing row 3632/4850
#
# Processing row 3633/4850
#
# Processing row 3634/4850
#
# Processing row 3635/4850
#
# Processing row 3636/4850
#
# Processing row 3637/4850
#
# Processing row 3638/4850
#
# Processing row 3639/4850
#
# Processing row 3640/4850
#
# Processing row 3641/4850
#
# Processing row 3642/4850
#
# Processing row 3643/4850
#
# Processing row 3644/4850
#
# Processing row 3645/4850
#
# Processing row 3646/4850
#
# Processing row 3647/4850
#
# Processing row 3648/4850
#
# Processing row 3649/4850
#
# Processing row 3650/4850
#
# Processing row 3651/4850
#
# Processing row 3652/4850
#
# Processing row 3653/4850
#
# Processing row 3654/4850
#
# Processing row 3655/4850
#
# Processing row 3656/4850
#
# Processing row 3657/4850
#
# Processing row 3658/4850
#
# Processing row 3659/4850
#
# Processing row 3660/4850
#
# Processing row 3661/4850
#
# Processing row 3662/4850
#
# Processing row 3663/4850
#
# Processing row 3664/4850
#
# Processing row 3665/4850
#
# Processing row 3666/4850
#
# Processing row 3667/4850
#
# Processing row 3668/4850
#
# Processing row 3669/4850
#
# Processing row 3670/4850
#
# Processing row 3671/4850
#
# Processing row 3672/4850
#
# Processing row 3673/4850
#
# Processing row 3674/4850
#
# Processing row 3675/4850
#
# Processing row 3676/4850
#
# Processing row 3677/4850
#
# Processing row 3678/4850
#
# Processing row 3679/4850
#
# Processing row 3680/4850
#
# Processing row 3681/4850
#
# Processing row 3682/4850
#
# Processing row 3683/4850
#
# Processing row 3684/4850
#
# Processing row 3685/4850
#
# Processing row 3686/4850
#
# Processing row 3687/4850
#
# Processing row 3688/4850
#
# Processing row 3689/4850
#
# Processing row 3690/4850
#
# Processing row 3691/4850
#
# Processing row 3692/4850
#
# Processing row 3693/4850
#
# Processing row 3694/4850
#
# Processing row 3695/4850
#
# Processing row 3696/4850
#
# Processing row 3697/4850
#
# Processing row 3698/4850
#
# Processing row 3699/4850
#
# Processing row 3700/4850
#
# Processing row 3701/4850
#
# Processing row 3702/4850
#
# Processing row 3703/4850
#
# Processing row 3704/4850
#
# Processing row 3705/4850
#
# Processing row 3706/4850
#
# Processing row 3707/4850
#
# Processing row 3708/4850
#
# Processing row 3709/4850
#
# Processing row 3710/4850
#
# Processing row 3711/4850
#
# Processing row 3712/4850
#
# Processing row 3713/4850
#
# Processing row 3714/4850
#
# Processing row 3715/4850
#
# Processing row 3716/4850
#
# Processing row 3717/4850
#
# Processing row 3718/4850
#
# Processing row 3719/4850
#
# Processing row 3720/4850
#
# Processing row 3721/4850
#
# Processing row 3722/4850
#
# Processing row 3723/4850
#
# Processing row 3724/4850
#
# Processing row 3725/4850
#
# Processing row 3726/4850
#
# Processing row 3727/4850
#
# Processing row 3728/4850
#
# Processing row 3729/4850
#
# Processing row 3730/4850
#
# Processing row 3731/4850
#
# Processing row 3732/4850
#
# Processing row 3733/4850
#
# Processing row 3734/4850
#
# Processing row 3735/4850
#
# Processing row 3736/4850
#
# Processing row 3737/4850
#
# Processing row 3738/4850
#
# Processing row 3739/4850
#
# Processing row 3740/4850
#
# Processing row 3741/4850
#
# Processing row 3742/4850
#
# Processing row 3743/4850
#
# Processing row 3744/4850
#
# Processing row 3745/4850
#
# Processing row 3746/4850
#
# Processing row 3747/4850
#
# Processing row 3748/4850
#
# Processing row 3749/4850
#
# Processing row 3750/4850
#
# Processing row 3751/4850
#
# Processing row 3752/4850
#
# Processing row 3753/4850
#
# Processing row 3754/4850
#
# Processing row 3755/4850
#
# Processing row 3756/4850
#
# Processing row 3757/4850
#
# Processing row 3758/4850
#
# Processing row 3759/4850
#
# Processing row 3760/4850
#
# Processing row 3761/4850
#
# Processing row 3762/4850
#
# Processing row 3763/4850
#
# Processing row 3764/4850
#
# Processing row 3765/4850
#
# Processing row 3766/4850
#
# Processing row 3767/4850
#
# Processing row 3768/4850
#
# Processing row 3769/4850
#
# Processing row 3770/4850
#
# Processing row 3771/4850
#
# Processing row 3772/4850
#
# Processing row 3773/4850
#
# Processing row 3774/4850
#
# Processing row 3775/4850
#
# Processing row 3776/4850
#
# Processing row 3777/4850
#
# Processing row 3778/4850
#
# Processing row 3779/4850
#
# Processing row 3780/4850
#
# Processing row 3781/4850
#
# Processing row 3782/4850
#
# Processing row 3783/4850
#
# Processing row 3784/4850
#
# Processing row 3785/4850
#
# Processing row 3786/4850
#
# Processing row 3787/4850
#
# Processing row 3788/4850
#
# Processing row 3789/4850
#
# Processing row 3790/4850
#
# Processing row 3791/4850
#
# Processing row 3792/4850
#
# Processing row 3793/4850
#
# Processing row 3794/4850
#
# Processing row 3795/4850
#
# Processing row 3796/4850
#
# Processing row 3797/4850
#
# Processing row 3798/4850
#
# Processing row 3799/4850
#
# Processing row 3800/4850
#
# Processing row 3801/4850
#
# Processing row 3802/4850
#
# Processing row 3803/4850
#
# Processing row 3804/4850
#
# Processing row 3805/4850
#
# Processing row 3806/4850
#
# Processing row 3807/4850
#
# Processing row 3808/4850
#
# Processing row 3809/4850
#
# Processing row 3810/4850
#
# Processing row 3811/4850
#
# Processing row 3812/4850
#
# Processing row 3813/4850
#
# Processing row 3814/4850
#
# Processing row 3815/4850
#
# Processing row 3816/4850
#
# Processing row 3817/4850
#
# Processing row 3818/4850
#
# Processing row 3819/4850
#
# Processing row 3820/4850
#
# Processing row 3821/4850
#
# Processing row 3822/4850
#
# Processing row 3823/4850
#
# Processing row 3824/4850
#
# Processing row 3825/4850
#
# Processing row 3826/4850
#
# Processing row 3827/4850
#
# Processing row 3828/4850
#
# Processing row 3829/4850
#
# Processing row 3830/4850
#
# Processing row 3831/4850
#
# Processing row 3832/4850
#
# Processing row 3833/4850
#
# Processing row 3834/4850
#
# Processing row 3835/4850
#
# Processing row 3836/4850
#
# Processing row 3837/4850
#
# Processing row 3838/4850
#
# Processing row 3839/4850
#
# Processing row 3840/4850
#
# Processing row 3841/4850
#
# Processing row 3842/4850
#
# Processing row 3843/4850
#
# Processing row 3844/4850
#
# Processing row 3845/4850
#
# Processing row 3846/4850
#
# Processing row 3847/4850
#
# Processing row 3848/4850
#
# Processing row 3849/4850
#
# Processing row 3850/4850
#
# Processing row 3851/4850
#
# Processing row 3852/4850
#
# Processing row 3853/4850
#
# Processing row 3854/4850
#
# Processing row 3855/4850
#
# Processing row 3856/4850
#
# Processing row 3857/4850
#
# Processing row 3858/4850
#
# Processing row 3859/4850
#
# Processing row 3860/4850
#
# Processing row 3861/4850
#
# Processing row 3862/4850
#
# Processing row 3863/4850
#
# Processing row 3864/4850
#
# Processing row 3865/4850
#
# Processing row 3866/4850
#
# Processing row 3867/4850
#
# Processing row 3868/4850
#
# Processing row 3869/4850
#
# Processing row 3870/4850
#
# Processing row 3871/4850
#
# Processing row 3872/4850
#
# Processing row 3873/4850
#
# Processing row 3874/4850
#
# Processing row 3875/4850
#
# Processing row 3876/4850
#
# Processing row 3877/4850
#
# Processing row 3878/4850
#
# Processing row 3879/4850
#
# Processing row 3880/4850
#
# Processing row 3881/4850
#
# Processing row 3882/4850
#
# Processing row 3883/4850
#
# Processing row 3884/4850
#
# Processing row 3885/4850
#
# Processing row 3886/4850
#
# Processing row 3887/4850
#
# Processing row 3888/4850
#
# Processing row 3889/4850
#
# Processing row 3890/4850
#
# Processing row 3891/4850
#
# Processing row 3892/4850
#
# Processing row 3893/4850
#
# Processing row 3894/4850
#
# Processing row 3895/4850
#
# Processing row 3896/4850
#
# Processing row 3897/4850
#
# Processing row 3898/4850
#
# Processing row 3899/4850
#
# Processing row 3900/4850
#
# Processing row 3901/4850
#
# Processing row 3902/4850
#
# Processing row 3903/4850
#
# Processing row 3904/4850
#
# Processing row 3905/4850
#
# Processing row 3906/4850
#
# Processing row 3907/4850
#
# Processing row 3908/4850
#
# Processing row 3909/4850
#
# Processing row 3910/4850
#
# Processing row 3911/4850
#
# Processing row 3912/4850
#
# Processing row 3913/4850
#
# Processing row 3914/4850
#
# Processing row 3915/4850
#
# Processing row 3916/4850
#
# Processing row 3917/4850
#
# Processing row 3918/4850
#
# Processing row 3919/4850
#
# Processing row 3920/4850
#
# Processing row 3921/4850
#
# Processing row 3922/4850
#
# Processing row 3923/4850
#
# Processing row 3924/4850
#
# Processing row 3925/4850
#
# Processing row 3926/4850
#
# Processing row 3927/4850
#
# Processing row 3928/4850
#
# Processing row 3929/4850
#
# Processing row 3930/4850
#
# Processing row 3931/4850
#
# Processing row 3932/4850
#
# Processing row 3933/4850
#
# Processing row 3934/4850
#
# Processing row 3935/4850
#
# Processing row 3936/4850
#
# Processing row 3937/4850
#
# Processing row 3938/4850
#
# Processing row 3939/4850
#
# Processing row 3940/4850
#
# Processing row 3941/4850
#
# Processing row 3942/4850
#
# Processing row 3943/4850
#
# Processing row 3944/4850
#
# Processing row 3945/4850
#
# Processing row 3946/4850
#
# Processing row 3947/4850
#
# Processing row 3948/4850
#
# Processing row 3949/4850
#
# Processing row 3950/4850
#
# Processing row 3951/4850
#
# Processing row 3952/4850
#
# Processing row 3953/4850
#
# Processing row 3954/4850
#
# Processing row 3955/4850
#
# Processing row 3956/4850
#
# Processing row 3957/4850
#
# Processing row 3958/4850
#
# Processing row 3959/4850
#
# Processing row 3960/4850
#
# Processing row 3961/4850
#
# Processing row 3962/4850
#
# Processing row 3963/4850
#
# Processing row 3964/4850
#
# Processing row 3965/4850
#
# Processing row 3966/4850
#
# Processing row 3967/4850
#
# Processing row 3968/4850
#
# Processing row 3969/4850
#
# Processing row 3970/4850
#
# Processing row 3971/4850
#
# Processing row 3972/4850
#
# Processing row 3973/4850
#
# Processing row 3974/4850
#
# Processing row 3975/4850
#
# Processing row 3976/4850
#
# Processing row 3977/4850
#
# Processing row 3978/4850
#
# Processing row 3979/4850
#
# Processing row 3980/4850
#
# Processing row 3981/4850
#
# Processing row 3982/4850
#
# Processing row 3983/4850
#
# Processing row 3984/4850
#
# Processing row 3985/4850
#
# Processing row 3986/4850
#
# Processing row 3987/4850
#
# Processing row 3988/4850
#
# Processing row 3989/4850
#
# Processing row 3990/4850
#
# Processing row 3991/4850
#
# Processing row 3992/4850
#
# Processing row 3993/4850
#
# Processing row 3994/4850
#
# Processing row 3995/4850
#
# Processing row 3996/4850
#
# Processing row 3997/4850
#
# Processing row 3998/4850
#
# Processing row 3999/4850
#
# Processing row 4000/4850
#
# Processing row 4001/4850
#
# Processing row 4002/4850
#
# Processing row 4003/4850
#
# Processing row 4004/4850
#
# Processing row 4005/4850
#
# Processing row 4006/4850
#
# Processing row 4007/4850
#
# Processing row 4008/4850
#
# Processing row 4009/4850
#
# Processing row 4010/4850
#
# Processing row 4011/4850
#
# Processing row 4012/4850
#
# Processing row 4013/4850
#
# Processing row 4014/4850
#
# Processing row 4015/4850
#
# Processing row 4016/4850
#
# Processing row 4017/4850
#
# Processing row 4018/4850
#
# Processing row 4019/4850
#
# Processing row 4020/4850
#
# Processing row 4021/4850
#
# Processing row 4022/4850
#
# Processing row 4023/4850
#
# Processing row 4024/4850
#
# Processing row 4025/4850
#
# Processing row 4026/4850
#
# Processing row 4027/4850
#
# Processing row 4028/4850
#
# Processing row 4029/4850
#
# Processing row 4030/4850
#
# Processing row 4031/4850
#
# Processing row 4032/4850
#
# Processing row 4033/4850
#
# Processing row 4034/4850
#
# Processing row 4035/4850
#
# Processing row 4036/4850
#
# Processing row 4037/4850
#
# Processing row 4038/4850
#
# Processing row 4039/4850
#
# Processing row 4040/4850
#
# Processing row 4041/4850
#
# Processing row 4042/4850
#
# Processing row 4043/4850
#
# Processing row 4044/4850
#
# Processing row 4045/4850
#
# Processing row 4046/4850
#
# Processing row 4047/4850
#
# Processing row 4048/4850
#
# Processing row 4049/4850
#
# Processing row 4050/4850
#
# Processing row 4051/4850
#
# Processing row 4052/4850
#
# Processing row 4053/4850
#
# Processing row 4054/4850
#
# Processing row 4055/4850
#
# Processing row 4056/4850
#
# Processing row 4057/4850
#
# Processing row 4058/4850
#
# Processing row 4059/4850
#
# Processing row 4060/4850
#
# Processing row 4061/4850
#
# Processing row 4062/4850
#
# Processing row 4063/4850
#
# Processing row 4064/4850
#
# Processing row 4065/4850
#
# Processing row 4066/4850
#
# Processing row 4067/4850
#
# Processing row 4068/4850
#
# Processing row 4069/4850
#
# Processing row 4070/4850
#
# Processing row 4071/4850
#
# Processing row 4072/4850
#
# Processing row 4073/4850
#
# Processing row 4074/4850
#
# Processing row 4075/4850
#
# Processing row 4076/4850
#
# Processing row 4077/4850
#
# Processing row 4078/4850
#
# Processing row 4079/4850
#
# Processing row 4080/4850
#
# Processing row 4081/4850
#
# Processing row 4082/4850
#
# Processing row 4083/4850
#
# Processing row 4084/4850
#
# Processing row 4085/4850
#
# Processing row 4086/4850
#
# Processing row 4087/4850
#
# Processing row 4088/4850
#
# Processing row 4089/4850
#
# Processing row 4090/4850
#
# Processing row 4091/4850
#
# Processing row 4092/4850
#
# Processing row 4093/4850
#
# Processing row 4094/4850
#
# Processing row 4095/4850
#
# Processing row 4096/4850
#
# Processing row 4097/4850
#
# Processing row 4098/4850
#
# Processing row 4099/4850
#
# Processing row 4100/4850
#
# Processing row 4101/4850
#
# Processing row 4102/4850
#
# Processing row 4103/4850
#
# Processing row 4104/4850
#
# Processing row 4105/4850
#
# Processing row 4106/4850
#
# Processing row 4107/4850
#
# Processing row 4108/4850
#
# Processing row 4109/4850
#
# Processing row 4110/4850
#
# Processing row 4111/4850
#
# Processing row 4112/4850
#
# Processing row 4113/4850
#
# Processing row 4114/4850
#
# Processing row 4115/4850
#
# Processing row 4116/4850
#
# Processing row 4117/4850
#
# Processing row 4118/4850
#
# Processing row 4119/4850
#
# Processing row 4120/4850
#
# Processing row 4121/4850
#
# Processing row 4122/4850
#
# Processing row 4123/4850
#
# Processing row 4124/4850
#
# Processing row 4125/4850
#
# Processing row 4126/4850
#
# Processing row 4127/4850
#
# Processing row 4128/4850
#
# Processing row 4129/4850
#
# Processing row 4130/4850
#
# Processing row 4131/4850
#
# Processing row 4132/4850
#
# Processing row 4133/4850
#
# Processing row 4134/4850
#
# Processing row 4135/4850
#
# Processing row 4136/4850
#
# Processing row 4137/4850
#
# Processing row 4138/4850
#
# Processing row 4139/4850
#
# Processing row 4140/4850
#
# Processing row 4141/4850
#
# Processing row 4142/4850
#
# Processing row 4143/4850
#
# Processing row 4144/4850
#
# Processing row 4145/4850
#
# Processing row 4146/4850
#
# Processing row 4147/4850
#
# Processing row 4148/4850
#
# Processing row 4149/4850
#
# Processing row 4150/4850
#
# Processing row 4151/4850
#
# Processing row 4152/4850
#
# Processing row 4153/4850
#
# Processing row 4154/4850
#
# Processing row 4155/4850
#
# Processing row 4156/4850
#
# Processing row 4157/4850
#
# Processing row 4158/4850
#
# Processing row 4159/4850
#
# Processing row 4160/4850
#
# Processing row 4161/4850
#
# Processing row 4162/4850
#
# Processing row 4163/4850
#
# Processing row 4164/4850
#
# Processing row 4165/4850
#
# Processing row 4166/4850
#
# Processing row 4167/4850
#
# Processing row 4168/4850
#
# Processing row 4169/4850
#
# Processing row 4170/4850
#
# Processing row 4171/4850
#
# Processing row 4172/4850
#
# Processing row 4173/4850
#
# Processing row 4174/4850
#
# Processing row 4175/4850
#
# Processing row 4176/4850
#
# Processing row 4177/4850
#
# Processing row 4178/4850
#
# Processing row 4179/4850
#
# Processing row 4180/4850
#
# Processing row 4181/4850
#
# Processing row 4182/4850
#
# Processing row 4183/4850
#
# Processing row 4184/4850
#
# Processing row 4185/4850
#
# Processing row 4186/4850
#
# Processing row 4187/4850
#
# Processing row 4188/4850
#
# Processing row 4189/4850
#
# Processing row 4190/4850
#
# Processing row 4191/4850
#
# Processing row 4192/4850
#
# Processing row 4193/4850
#
# Processing row 4194/4850
#
# ...
#
# Processing row 4236/4850
#
# Processing row 4237/4850
#
# Processing row 4238/4850
#
# Processing row 4239/4850
#
# Processing row 4240/4850
#
# Processing row 4241/4850
#
# Processing row 4242/4850
#
# Processing row 4243/4850
#
# Processing row 4244/4850
#
# Processing row 4245/4850
#
# Processing row 4246/4850
#
# Processing row 4247/4850
#
# Processing row 4248/4850
#
# Processing row 4249/4850
#
# Processing row 4250/4850
#
# Processing row 4251/4850
#
# Processing row 4252/4850
#
# Processing row 4253/4850
#
# Processing row 4254/4850
#
# Processing row 4255/4850
#
# Processing row 4256/4850
#
# Processing row 4257/4850
#
# Processing row 4258/4850
#
# Processing row 4259/4850
#
# Processing row 4260/4850
#
# Processing row 4261/4850
#
# Processing row 4262/4850
#
# Processing row 4263/4850
#
# Processing row 4264/4850
#
# Processing row 4265/4850
#
# Processing row 4266/4850
#
# Processing row 4267/4850
#
# Processing row 4268/4850
#
# Processing row 4269/4850
#
# Processing row 4270/4850
#
# Processing row 4271/4850
#
# Processing row 4272/4850
#
# Processing row 4273/4850
#
# Processing row 4274/4850
#
# Processing row 4275/4850
#
# Processing row 4276/4850
#
# Processing row 4277/4850
#
# Processing row 4278/4850
#
# Processing row 4279/4850
#
# Processing row 4280/4850
#
# Processing row 4281/4850
#
# Processing row 4282/4850
#
# Processing row 4283/4850
#
# Processing row 4284/4850
#
# Processing row 4285/4850
#
# Processing row 4286/4850
#
# Processing row 4287/4850
#
# Processing row 4288/4850
#
# Processing row 4289/4850
#
# Processing row 4290/4850
#
# Processing row 4291/4850
#
# Processing row 4292/4850
#
# Processing row 4293/4850
#
# Processing row 4294/4850
#
# Processing row 4295/4850
#
# Processing row 4296/4850
#
# Processing row 4297/4850
#
# Processing row 4298/4850
#
# Processing row 4299/4850
#
# Processing row 4300/4850
#
# Processing row 4301/4850
#
# Processing row 4302/4850
#
# Processing row 4303/4850
#
# Processing row 4304/4850
#
# Processing row 4305/4850
#
# Processing row 4306/4850
#
# Processing row 4307/4850
#
# Processing row 4308/4850
#
# Processing row 4309/4850
#
# Processing row 4310/4850
#
# Processing row 4311/4850
#
# Processing row 4312/4850
#
# Processing row 4313/4850
#
# Processing row 4314/4850
#
# Processing row 4315/4850
#
# Processing row 4316/4850
#
# Processing row 4317/4850
#
# Processing row 4318/4850
#
# Processing row 4319/4850
#
# Processing row 4320/4850
#
# Processing row 4321/4850
#
# Processing row 4322/4850
#
# Processing row 4323/4850
#
# Processing row 4324/4850
#
# Processing row 4325/4850
#
# Processing row 4326/4850
#
# Processing row 4327/4850
#
# Processing row 4328/4850
#
# Processing row 4329/4850
#
# Processing row 4330/4850
#
# Processing row 4331/4850
#
# Processing row 4332/4850
#
# Processing row 4333/4850
#
# Processing row 4334/4850
#
# Processing row 4335/4850
#
# Processing row 4336/4850
#
# Processing row 4337/4850
#
# Processing row 4338/4850
#
# Processing row 4339/4850
#
# Processing row 4340/4850
#
# Processing row 4341/4850
#
# Processing row 4342/4850
#
# Processing row 4343/4850
#
# Processing row 4344/4850
#
# Processing row 4345/4850
#
# Processing row 4346/4850
#
# Processing row 4347/4850
#
# Processing row 4348/4850
#
# Processing row 4349/4850
#
# Processing row 4350/4850
#
# Processing row 4351/4850
#
# Processing row 4352/4850
#
# Processing row 4353/4850
#
# Processing row 4354/4850
#
# Processing row 4355/4850
#
# Processing row 4356/4850
#
# Processing row 4357/4850
#
# Processing row 4358/4850
#
# Processing row 4359/4850
#
# Processing row 4360/4850
#
# Processing row 4361/4850
#
# Processing row 4362/4850
#
# Processing row 4363/4850
#
# Processing row 4364/4850
#
# Processing row 4365/4850
#
# Processing row 4366/4850
#
# Processing row 4367/4850
#
# Processing row 4368/4850
#
# Processing row 4369/4850
#
# Processing row 4370/4850
#
# Processing row 4371/4850
#
# Processing row 4372/4850
#
# Processing row 4373/4850
#
# Processing row 4374/4850
#
# Processing row 4375/4850
#
# Processing row 4376/4850
#
# Processing row 4377/4850
#
# Processing row 4378/4850
#
# Processing row 4379/4850
#
# Processing row 4380/4850
#
# Processing row 4381/4850
#
# Processing row 4382/4850
#
# Processing row 4383/4850
#
# Processing row 4384/4850
#
# Processing row 4385/4850
#
# Processing row 4386/4850
#
# Processing row 4387/4850
#
# Processing row 4388/4850
#
# Processing row 4389/4850
#
# Processing row 4390/4850
#
# Processing row 4391/4850
#
# Processing row 4392/4850
#
# Processing row 4393/4850
#
# Processing row 4394/4850
#
# Processing row 4395/4850
#
# Processing row 4396/4850
#
# Processing row 4397/4850
#
# Processing row 4398/4850
#
# Processing row 4399/4850
#
# Processing row 4400/4850
#
# Processing row 4401/4850
#
# Processing row 4402/4850
#
# Processing row 4403/4850
#
# Processing row 4404/4850
#
# Processing row 4405/4850
#
# Processing row 4406/4850
#
# Processing row 4407/4850
#
# Processing row 4408/4850
#
# Processing row 4409/4850
#
# Processing row 4410/4850
#
# Processing row 4411/4850
#
# Processing row 4412/4850
#
# Processing row 4413/4850
#
# Processing row 4414/4850
#
# Processing row 4415/4850
#
# Processing row 4416/4850
#
# Processing row 4417/4850
#
# Processing row 4418/4850
#
# Processing row 4419/4850
#
# Processing row 4420/4850
#
# Processing row 4421/4850
#
# Processing row 4422/4850
#
# Processing row 4423/4850
#
# Processing row 4424/4850
#
# Processing row 4425/4850
#
# Processing row 4426/4850
#
# Processing row 4427/4850
#
# Processing row 4428/4850
#
# Processing row 4429/4850
#
# Processing row 4430/4850
#
# Processing row 4431/4850
#
# Processing row 4432/4850
#
# Processing row 4433/4850
#
# Processing row 4434/4850
#
# Processing row 4435/4850
#
# Processing row 4436/4850
#
# Processing row 4437/4850
#
# Processing row 4438/4850
#
# Processing row 4439/4850
#
# Processing row 4440/4850
#
# Processing row 4441/4850
#
# Processing row 4442/4850
#
# Processing row 4443/4850
#
# Processing row 4444/4850
#
# Processing row 4445/4850
#
# Processing row 4446/4850
#
# Processing row 4447/4850
#
# Processing row 4448/4850
#
# Processing row 4449/4850
#
# Processing row 4450/4850
#
# Processing row 4451/4850
#
# Processing row 4452/4850
#
# Processing row 4453/4850
#
# Processing row 4454/4850
#
# Processing row 4455/4850
#
# Processing row 4456/4850
#
# Processing row 4457/4850
#
# Processing row 4458/4850
#
# Processing row 4459/4850
#
# Processing row 4460/4850
#
# Processing row 4461/4850
#
# Processing row 4462/4850
#
# Processing row 4463/4850
#
# Processing row 4464/4850
#
# Processing row 4465/4850
#
# Processing row 4466/4850
#
# Processing row 4467/4850
#
# Processing row 4468/4850
#
# Processing row 4469/4850
#
# Processing row 4470/4850
#
# Processing row 4471/4850
#
# Processing row 4472/4850
#
# Processing row 4473/4850
#
# Processing row 4474/4850
#
# Processing row 4475/4850
#
# Processing row 4476/4850
#
# Processing row 4477/4850
#
# Processing row 4478/4850
#
# Processing row 4479/4850
#
# Processing row 4480/4850
#
# Processing row 4481/4850
#
# Processing row 4482/4850
#
# Processing row 4483/4850
#
# Processing row 4484/4850
#
# Processing row 4485/4850
#
# Processing row 4486/4850
#
# Processing row 4487/4850
#
# Processing row 4488/4850
#
# Processing row 4489/4850
#
# Processing row 4490/4850
#
# Processing row 4491/4850
#
# Processing row 4492/4850
#
# Processing row 4493/4850
#
# Processing row 4494/4850
#
# Processing row 4495/4850
#
# Processing row 4496/4850
#
# Processing row 4497/4850
#
# Processing row 4498/4850
#
# Processing row 4499/4850
#
# Processing row 4500/4850
#
# Processing row 4501/4850
#
# Processing row 4502/4850
#
# Processing row 4503/4850
#
# Processing row 4504/4850
#
# Processing row 4505/4850
#
# Processing row 4506/4850
#
# Processing row 4507/4850
#
# Processing row 4508/4850
#
# Processing row 4509/4850
#
# Processing row 4510/4850
#
# Processing row 4511/4850
#
# Processing row 4512/4850
#
# Processing row 4513/4850
#
# Processing row 4514/4850
#
# Processing row 4515/4850
#
# Processing row 4516/4850
#
# Processing row 4517/4850
#
# Processing row 4518/4850
#
# Processing row 4519/4850
#
# Processing row 4520/4850
#
# Processing row 4521/4850
#
# Processing row 4522/4850
#
# Processing row 4523/4850
#
# Processing row 4524/4850
#
# Processing row 4525/4850
#
# Processing row 4526/4850
#
# Processing row 4527/4850
#
# Processing row 4528/4850
#
# Processing row 4529/4850
#
# Processing row 4530/4850
#
# Processing row 4531/4850
#
# Processing row 4532/4850
#
# Processing row 4533/4850
#
# Processing row 4534/4850
#
# Processing row 4535/4850
#
# Processing row 4536/4850
#
# Processing row 4537/4850
#
# Processing row 4538/4850
#
# Processing row 4539/4850
#
# Processing row 4540/4850
#
# Processing row 4541/4850
#
# Processing row 4542/4850
#
# Processing row 4543/4850
#
# Processing row 4544/4850
#
# Processing row 4545/4850
#
# Processing row 4546/4850
#
# Processing row 4547/4850
#
# Processing row 4548/4850
#
# Processing row 4549/4850
#
# Processing row 4550/4850
#
# Processing row 4551/4850
#
# Processing row 4552/4850
#
# Processing row 4553/4850
#
# Processing row 4554/4850
#
# Processing row 4555/4850
#
# Processing row 4556/4850
#
# Processing row 4557/4850
#
# Processing row 4558/4850
#
# Processing row 4559/4850
#
# Processing row 4560/4850
#
# Processing row 4561/4850
#
# Processing row 4562/4850
#
# Processing row 4563/4850
#
# Processing row 4564/4850
#
# Processing row 4565/4850
#
# Processing row 4566/4850
#
# Processing row 4567/4850
#
# Processing row 4568/4850
#
# Processing row 4569/4850
#
# Processing row 4570/4850
#
# Processing row 4571/4850
#
# Processing row 4572/4850
#
# Processing row 4573/4850
#
# Processing row 4574/4850
#
# Processing row 4575/4850
#
# Processing row 4576/4850
#
# Processing row 4577/4850
#
# Processing row 4578/4850
#
# Processing row 4579/4850
#
# Processing row 4580/4850
#
# Processing row 4581/4850
#
# Processing row 4582/4850
#
# Processing row 4583/4850
#
# Processing row 4584/4850
#
# Processing row 4585/4850
#
# Processing row 4586/4850
#
# Processing row 4587/4850
#
# Processing row 4588/4850
#
# Processing row 4589/4850
#
# Processing row 4590/4850
#
# Processing row 4591/4850
#
# Processing row 4592/4850
#
# Processing row 4593/4850
#
# Processing row 4594/4850
#
# Processing row 4595/4850
#
# Processing row 4596/4850
#
# Processing row 4597/4850
#
# Processing row 4598/4850
#
# Processing row 4599/4850
#
# Processing row 4600/4850
#
# Processing row 4601/4850
#
# Processing row 4602/4850
#
# Processing row 4603/4850
#
# Processing row 4604/4850
#
# Processing row 4605/4850
#
# Processing row 4606/4850
#
# Processing row 4607/4850
#
# Processing row 4608/4850
#
# Processing row 4609/4850
#
# Processing row 4610/4850
#
# Processing row 4611/4850
#
# Processing row 4612/4850
#
# Processing row 4613/4850
#
# Processing row 4614/4850
#
# Processing row 4615/4850
#
# Processing row 4616/4850
#
# Processing row 4617/4850
#
# Processing row 4618/4850
#
# Processing row 4619/4850
#
# Processing row 4620/4850
#
# Processing row 4621/4850
#
# Processing row 4622/4850
#
# Processing row 4623/4850
#
# Processing row 4624/4850
#
# Processing row 4625/4850
#
# Processing row 4626/4850
#
# Processing row 4627/4850
#
# Processing row 4628/4850
#
# Processing row 4629/4850
#
# Processing row 4630/4850
#
# Processing row 4631/4850
#
# Processing row 4632/4850
#
# Processing row 4633/4850
#
# Processing row 4634/4850
#
# Processing row 4635/4850
#
# Processing row 4636/4850
#
# Processing row 4637/4850
#
# Processing row 4638/4850
#
# Processing row 4639/4850
#
# Processing row 4640/4850
#
# Processing row 4641/4850
#
# Processing row 4642/4850
#
# Processing row 4643/4850
#
# Processing row 4644/4850
#
# Processing row 4645/4850
#
# Processing row 4646/4850
#
# Processing row 4647/4850
#
# Processing row 4648/4850
#
# Processing row 4649/4850
#
# Processing row 4650/4850
#
# Processing row 4651/4850
#
# Processing row 4652/4850
#
# Processing row 4653/4850
#
# Processing row 4654/4850
#
# Processing row 4655/4850
#
# Processing row 4656/4850
#
# Processing row 4657/4850
#
# Processing row 4658/4850
#
# Processing row 4659/4850
#
# Processing row 4660/4850
#
# Processing row 4661/4850
#
# Processing row 4662/4850
#
# Processing row 4663/4850
#
# Processing row 4664/4850
#
# Processing row 4665/4850
#
# Processing row 4666/4850
#
# Processing row 4667/4850
#
# Processing row 4668/4850
#
# Processing row 4669/4850
#
# Processing row 4670/4850
#
# Processing row 4671/4850
#
# Processing row 4672/4850
#
# Processing row 4673/4850
#
# Processing row 4674/4850
#
# Processing row 4675/4850
#
# Processing row 4676/4850
#
# Processing row 4677/4850
#
# Processing row 4678/4850
#
# Processing row 4679/4850
#
# Processing row 4680/4850
#
# Processing row 4681/4850
#
# Processing row 4682/4850
#
# Processing row 4683/4850
#
# Processing row 4684/4850
#
# Processing row 4685/4850
#
# Processing row 4686/4850
#
# Processing row 4687/4850
#
# Processing row 4688/4850
#
# Processing row 4689/4850
#
# Processing row 4690/4850
#
# Processing row 4691/4850
#
# Processing row 4692/4850
#
# Processing row 4693/4850
#
# Processing row 4694/4850
#
# Processing row 4695/4850
#
# Processing row 4696/4850
#
# Processing row 4697/4850
#
# Processing row 4698/4850
#
# Processing row 4699/4850
#
# Processing row 4700/4850
#
# Processing row 4701/4850
#
# Processing row 4702/4850
#
# Processing row 4703/4850
#
# Processing row 4704/4850
#
# Processing row 4705/4850
#
# Processing row 4706/4850
#
# Processing row 4707/4850
#
# Processing row 4708/4850
#
# Processing row 4709/4850
#
# Processing row 4710/4850
#
# Processing row 4711/4850
#
# Processing row 4712/4850
#
# Processing row 4713/4850
#
# Processing row 4714/4850
#
# Processing row 4715/4850
#
# Processing row 4716/4850
#
# Processing row 4717/4850
#
# Processing row 4718/4850
#
# Processing row 4719/4850
#
# Processing row 4720/4850
#
# Processing row 4721/4850
#
# Processing row 4722/4850
#
# Processing row 4723/4850
#
# Processing row 4724/4850
#
# Processing row 4725/4850
#
# Processing row 4726/4850
#
# Processing row 4727/4850
#
# Processing row 4728/4850
#
# Processing row 4729/4850
#
# Processing row 4730/4850
#
# Processing row 4731/4850
#
# Processing row 4732/4850
#
# Processing row 4733/4850
#
# Processing row 4734/4850
#
# Processing row 4735/4850
#
# Processing row 4736/4850
#
# Processing row 4737/4850
#
# Processing row 4738/4850
#
# Processing row 4739/4850
#
# Processing row 4740/4850
#
# Processing row 4741/4850
#
# Processing row 4742/4850
#
# Processing row 4743/4850
#
# Processing row 4744/4850
#
# Processing row 4745/4850
#
# Processing row 4746/4850
#
# Processing row 4747/4850
#
# Processing row 4748/4850
#
# Processing row 4749/4850
#
# Processing row 4750/4850
#
# Processing row 4751/4850
#
# Processing row 4752/4850
#
# Processing row 4753/4850
#
# Processing row 4754/4850
#
# Processing row 4755/4850
#
# Processing row 4756/4850
#
# Processing row 4757/4850
#
# Processing row 4758/4850
#
# Processing row 4759/4850
#
# Processing row 4760/4850
#
# Processing row 4761/4850
#
# Processing row 4762/4850
#
# Processing row 4763/4850
#
# Processing row 4764/4850
#
# Processing row 4765/4850
#
# Processing row 4766/4850
#
# Processing row 4767/4850
#
# Processing row 4768/4850
#
# Processing row 4769/4850
#
# Processing row 4770/4850
#
# Processing row 4771/4850
#
# Processing row 4772/4850
#
# Processing row 4773/4850
#
# Processing row 4774/4850
#
# Processing row 4775/4850
#
# Processing row 4776/4850
#
# Processing row 4777/4850
#
# Processing row 4778/4850
#
# Processing row 4779/4850
#
# Processing row 4780/4850
#
# Processing row 4781/4850
#
# Processing row 4782/4850
#
# Processing row 4783/4850
#
# Processing row 4784/4850
#
# Processing row 4785/4850
#
# Processing row 4786/4850
#
# Processing row 4787/4850
#
# Processing row 4788/4850
#
# Processing row 4789/4850
#
# Processing row 4790/4850
#
# Processing row 4791/4850
#
# Processing row 4792/4850
#
# Processing row 4793/4850
#
# Processing row 4794/4850
#
# Processing row 4795/4850
#
# Processing row 4796/4850
#
# Processing row 4797/4850
#
# Processing row 4798/4850
#
# Processing row 4799/4850
#
# Processing row 4800/4850
#
# Processing row 4801/4850
#
# Processing row 4802/4850
#
# Processing row 4803/4850
#
# Processing row 4804/4850
#
# Processing row 4805/4850
#
# Processing row 4806/4850
#
# Processing row 4807/4850
#
# Processing row 4808/4850
#
# Processing row 4809/4850
#
# Processing row 4810/4850
#
# Processing row 4811/4850
#
# Processing row 4812/4850
#
# Processing row 4813/4850
#
# Processing row 4814/4850
#
# Processing row 4815/4850
#
# Processing row 4816/4850
#
# Processing row 4817/4850
#
# Processing row 4818/4850
#
# Processing row 4819/4850
#
# Processing row 4820/4850
#
# Processing row 4821/4850
#
# Processing row 4822/4850
#
# Processing row 4823/4850
#
# Processing row 4824/4850
#
# Processing row 4825/4850
#
# Processing row 4826/4850
#
# Processing row 4827/4850
#
# Processing row 4828/4850
#
# Processing row 4829/4850
#
# Processing row 4830/4850
#
# Processing row 4831/4850
#
# Processing row 4832/4850
#
# Processing row 4833/4850
#
# Processing row 4834/4850
#
# Processing row 4835/4850
#
# Processing row 4836/4850
#
# Processing row 4837/4850
#
# Processing row 4838/4850
#
# Processing row 4839/4850
#
# Processing row 4840/4850
#
# Processing row 4841/4850
#
# Processing row 4842/4850
#
# Processing row 4843/4850
#
# Processing row 4844/4850
#
# Processing row 4845/4850
#
# Processing row 4846/4850
#
# Processing row 4847/4850
#
# Processing row 4848/4850
#
# Processing row 4849/4850
#
# Processing row 4850/4850
